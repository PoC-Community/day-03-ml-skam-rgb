# %% [markdown]
# # ~ PoC AI Pool 2025 ~
# - ## Day 2: Understand Machine Learning
#     - ### Module 1: Linear Regression
# -----------

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# Welcome th the second day of your PoC AI Pool !
#
# *We had to make sure everyone was up to speed on basic python (and ai-related python libs) knowledge before heading into the main topic of this Pool: **machine learning** !*
#
# Yesterday, you learned some very useful skills which we'll put into practice in order to build our very first **machine learning project** :
#
# - python
# - numpy -> (to work with huge numbers and arrays)
# - matplotlib -> (to display graphs and visualise data)
# - pandas -> (to edit and analyse data)
#
# Today we delve deeper into the theory by entering in the world of **machine learning**. This notebook introduce the concept of *Linear Regression* that are the simpliest function to train.
#
# The problem you will encounter today is simply the multiplication by 2.
# Here the theory to understand it better :

# %% [markdown]
# ---
# ## 1.0 The theory

# %% [markdown]
# `Primary what is machine learning ?`

# %% [markdown]
# Imagine that you have a mathematical (polynomial) function like :
#
# ![polynomial_function.png](attachment:polynomial_function.png)

# %% [markdown]
# With an input of 1 or 3 the output will be :
#
# ![example_polynomial_function.png](attachment:example_polynomial_function.png)

# %% [markdown]
# Like easy for now, but let's imagine another function called m :
#
# ![m_function.png](attachment:m_function.png)

# %% [markdown]
# Strange we don't know the function inside, other wise we know that for an input of 1 and 3 the output will also be (like other example):
#
# ![example_m-function.png](attachment:example_m-function.png)

# %% [markdown]
# We can say that we have a dataset of input and output (all the example above) but we don't now the formula to transform `x`into `y` and that's were *machine learning come* !
#
# So machine learning is the process to find an algorithm (here a simple function) that fit with all the data we give it in parameter
#
# ![m_machine_learning.png](attachment:m_machine_learning.png)

# %% [markdown]
# Many technics are possible in machine learning like the famous neural networks, the random forest, the k-nearest neighboors, and the most simple technique : the linear regression !

# %% [markdown]
# ---
# ## 2.0 The Linear Regression

# %% [markdown]
# ### Step 1: Understanding the Formula
#
#
# the formula for linear regression is just the representation of a simple polynomial function like this :
#
# $$ f(x) = a \cdot x + b $$
#
# But today, we’re not going to stick to the pure math version. Instead, we’ll look at its “machine learning transcription” (same idea but with different names) since we’re going to talk about neurons and all that jazz. Yeah, I know we’re not technically in neural networks yet, but hey, this formula works for a single neuron too! Here’s the breakdown:
#
# A neuron is basically the simplest function in machine learning. With one input and one output, its formula looks like this:
#
# $$ y = x \cdot w + b $$
#
# Where:
# -	 $ x $ is the input.
# -	 $ w $ is the weight of the neuron.
# -	 $ y $ is the output.
# -    $ b $ is the bias of the neuron, which is just a value we add to the result.
#
# If we had two inputs, the formula would expand to:
#
# $$ y = x_1 \cdot w_1 + x_2 \cdot w_2 + b $$
#
# The goal here is to modifie $ w $ and  $b$  so that our predicted output $( y_{\text{pred}} )$ matches the actual output $( y )$.
#
# Alright, let’s get started by creating a dataset for our neuron to learn from!

# %%
# Task: Create the training set
train_set = [
    [0, 0],
    [1, 2],
    [2, 4],
    [3, 6],
    [4, 8],
    [5, 10]
]
print("Training Set:", train_set)
# Out:
# Training Set: [[0, 0], [1, 2], [2, 4], [3, 6], [4, 8], [5, 10]]

# %%
# Task: Visualize the training set

x = [i[0] for i in train_set]
y = [i[1] for i in train_set]

plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 12])
plt.show()

# %% [markdown]
# ### Step 2: Initialize the Weight and Bias
#
# We need to initialize both `w` and `b` with random values beetwen 0 and 10 at the start :

# %%
import random
random.seed(0)


mini = 0
maxi = 10

#TODO: randomise the weight and bias beetwen 0 and 10
w = random.uniform(mini, maxi)
b = random.uniform(mini, maxi)

print("Initial Weight:", w)
print("Initial Bias:", b)

assert w > 8.44 and w < 8.45, "Weight is not correct"
assert b > 7.57 and b < 7.58, "Bias is not correct"
# Out:
# Initial Weight: 8.444218515250482
# Initial Bias: 7.579544029403024

# %% [markdown]
# ### step 3 : Make prediction using the neuron formula
#
# With the formula of above, calculate the `y_pred` of each input `x` in the train_set in a function call **forward**

# %%
#TODO : Define the forward function -> neuron function
def forward(x):
    return x * w + b

#TODO: Test the forward function
for x, y in train_set:
    y_pred = forward(x)
    print("Prediction:", y_pred, "Actual:", y)

assert forward(0) > 7.57 and forward(0) < 7.58, "Test Failed"
# Out:
# Prediction: 7.579544029403024 Actual: 0
# Prediction: 16.023762544653508 Actual: 2
# Prediction: 24.467981059903988 Actual: 4
# Prediction: 32.91219957515447 Actual: 6
# Prediction: 41.35641809040495 Actual: 8
# Prediction: 49.800636605655434 Actual: 10

# %%
# graph of the prediction and the actual data
x = [i[0] for i in train_set]
y = [i[1] for i in train_set]
y_pred = [forward(i) for i in x]

plt.plot(x, y, 'ro')
plt.plot(x, y_pred, 'bo')
plt.axis([0, 6, 0, 50])
plt.show()

# %% [markdown]
# As you can see, there is a significant difference between the prediction and the result, which we refer to as the error.  To measure this error, we use something called a loss function. The main goal is to minimize the loss function as much as possible, ideally getting it as close to zero as we can.
#
# One common way to calculate this error is by using the Mean Squared Error (MSE). First, we measure how far the prediction is from the actual output using this formula:
#
# $$ \text{Error} = y - y_{\text{pred}} $$
#
# Then, we square this error to make sure it’s always positive:
#
# $$ \text{Error Squared} = (y - y_{\text{pred}})^2 $$
#
# Finally, we sum up all these squared errors across the dataset and take the average to get the Mean Squared Error (MSE), which is one of the most popular loss functions out there:
#
# $$ \text{MSE} = \frac{1}{n} \sum_{i=1}^n (y_i - y_{\text{pred},i})^2 $$
#
# ![mse_loss_explication.png](attachment:mse_loss_explication.png)

# %% [markdown]
# *You only need to set up a squared error since we’re learning example by example, so there’s no need to sum anything! But hey, as a bonus, you could try implementing it in a **mean_squared_error** function :)*

# %%
#TODO: Define the loss function
def squared_error(y, y_pred):
    x = pow(y - y_pred, 2)
    return x

#TODO: Test the Squared loss function
for x, y in train_set:
    error = squared_error(y, forward(x))
    print("Error:", error)
# Out:
# Error: 57.44948769365903
# Error: 196.66591590882663
# Error: 418.93824866858836
# Error: 724.2664859729443
# Error: 1112.6506278218947
# Error: 1584.0906742154393

# %% [markdown]
# ### step 6 : Calcule the derivative
#
# After get this loss we need to reduce it near 0 ! To move from just measuring the error to actually reducing it, we need to figure out in which direction (+ or -) and by how much change our parameters `w`and `b`. This is when derivatives (the slope of your loss function) come in !
#
# Why Derivatives?
#
# •	A derivative tells us how fast the loss changes as we vary a parameter.
#
# •	If the derivative is large and positive, it means the loss will decrease if we move the parameter in the negative direction.
#
# •	If the derivative is large and negative, it means the loss will decrease if we move the parameter in the positive direction.
#
# For a single data point (x, y), the derivative of w is:
#
#
# Derivative for `w`
#
# $$
# \frac{\partial L}{\partial w}
# = 2 x \bigl(y - ypred\bigr).
# $$
#
# Derivative for `b`
#
# $$
# \frac{\partial L}{\partial b} = 2 \bigl(y - ypred\bigr).
# $$
#
# *Bonus : To better understand and apply the derivative of the function MSE with the linear regression, try calculating it manually and use the principe of [chain rule](https://www.youtube.com/watch?v=NO3AqAaAE6o) ! :)*
#
# chain rule :
#
# $$
# \frac{\partial L}{\partial w} = \frac{\partial L}{\partial y_{\text{pred}}} \cdot \frac{\partial y_{\text{pred}}}{\partial w}.
# $$

# %%
#TODO : setup the derivative of the loss function
def derivative_w(x, y, y_pred):
    return 2 * x * (y_pred - y)

def derivative_b(y, y_pred):
    return 2 * (y_pred - y)

def derivative(x, y, y_pred):
    return (derivative_w(x, y, y_pred), derivative_b(y, y_pred))


# Print the result of the derivative
for x, y in train_set:
    print(derivative(x, y, forward(x)))
    derivative_weight, derivative_bias = derivative(x, y, forward(x))

    print(f"x: {x} ; y: {y} -> y_pred: {forward(x):.3f} | Derivative Weight: {derivative_weight:.3f} | Derivative Bias: {derivative_bias:.3f}")
    # save the derivatives for after
    dw_values = [derivative_w(x, y, forward(x)) for x, y in train_set]
    db_values = [derivative_b(y, forward(x)) for x, y in train_set]
# Out:
# (0.0, 15.159088058806049)
# x: 0 ; y: 0 -> y_pred: 7.580 | Derivative Weight: 0.000 | Derivative Bias: 15.159
# (28.047525089307015, 28.047525089307015)
# x: 1 ; y: 2 -> y_pred: 16.024 | Derivative Weight: 28.048 | Derivative Bias: 28.048
# (81.87192423961595, 40.935962119807975)
# x: 2 ; y: 4 -> y_pred: 24.468 | Derivative Weight: 81.872 | Derivative Bias: 40.936
# (161.47319745092682, 53.824399150308935)
# x: 3 ; y: 6 -> y_pred: 32.912 | Derivative Weight: 161.473 | Derivative Bias: 53.824
# (266.8513447232396, 66.7128361808099)
# x: 4 ; y: 8 -> y_pred: 41.356 | Derivative Weight: 266.851 | Derivative Bias: 66.713
# (398.0063660565543, 79.60127321131087)
# x: 5 ; y: 10 -> y_pred: 49.801 | Derivative Weight: 398.006 | Derivative Bias: 79.601

# %%
plt.figure(figsize=(12, 6))

# Plot derivative of w
plt.subplot(1, 2, 1)
plt.plot(range(len(dw_values)), dw_values, marker='o', color='blue', label="Derivative of w")
plt.title("Derivative of Loss with respect to w")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/dw)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

# Plot derivative of b
plt.subplot(1, 2, 2)
plt.plot(range(len(db_values)), db_values, marker='o', color='orange', label="Derivative of b")
plt.title("Derivative of Loss with respect to b")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/db)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the larger the error, the larger the gradient will be. This is because the gradient measures how much the weights and biases should change to reduce the error. During training, this gradient is applied. What this means is that at every iteration, the gradient is used to update the corresponding values (weights and biases) so the function can learn and improve.
#
# This process is called gradient descent. It is the step where we adjust the weights and biases based on the gradient using the following formula:
#
# $$
# w = w - \eta \cdot \frac{\partial L}{\partial w}
# $$
#
# $$
# b = b - \eta \cdot \frac{\partial L}{\partial b}
# $$
#
# Here:
#
# •	￼ $ w $ $ b $  is the weight, and is the bias.
#
# •	￼ $ \eta $ is the learning rate, a parameter that controls how large each update step will be.
#
# •	￼ $ \frac{\partial L}{\partial w} $ and $ \frac{\partial L}{\partial b} $ are the gradients of the loss function with respect to the weight and bias.
#
#
# If the gradient is negative, the weight increases ; if the gradient is positive, the weight decreases. This helps reduce the loss over time.
#
# We don't add all the gradient to the weight, as you can see he his to big to reach the '2' value. To counter this problem, we only add a percentage of the gradient, and this percentage is choose by the learning rate.
#
# The learning rate plays a crucial role in how the model learns:
# 	•	A large learning rate makes the updates bigger, but the model might “overshoot” the optimal values and never fully converge to a solution.
# 	•	A small learning rate makes the updates smaller, which helps the model converge more precisely but takes a lot longer to reach the optimal solution.
#
# Choosing the right learning rate is critical. Too large, and the model might not learn properly; too small, and training might take too long, **choose carefully !**.

# %%
#TODO: Update the weight and bias
LEARNING_RATE = 0.01

w -= LEARNING_RATE * derivative_weight
b -= LEARNING_RATE * derivative_bias

print("Updated Weight:", w)
print("Updated Bias:", b)

for x, y in train_set:
    y_pred = forward(x)
    derivative_weight, derivative_bias = derivative(x, y, y_pred)
    print(f"x: {x} ; y: {y} -> y_pred: {y_pred:.3f} | Derivative Weight: {derivative_weight:.3f} | Derivative Bias: {derivative_bias:.3f}")
    # Plot the derivatives
    dw_values = [derivative_w(x, y, forward(x)) for x, y in train_set]
    db_values = [derivative_b(y, forward(x)) for x, y in train_set]
# Out:
# Updated Weight: 4.464154854684939
# Updated Bias: 6.783531297289915
# x: 0 ; y: 0 -> y_pred: 6.784 | Derivative Weight: 0.000 | Derivative Bias: 13.567
# x: 1 ; y: 2 -> y_pred: 11.248 | Derivative Weight: 18.495 | Derivative Bias: 18.495
# x: 2 ; y: 4 -> y_pred: 15.712 | Derivative Weight: 46.847 | Derivative Bias: 23.424
# x: 3 ; y: 6 -> y_pred: 20.176 | Derivative Weight: 85.056 | Derivative Bias: 28.352
# x: 4 ; y: 8 -> y_pred: 24.640 | Derivative Weight: 133.121 | Derivative Bias: 33.280
# x: 5 ; y: 10 -> y_pred: 29.104 | Derivative Weight: 191.043 | Derivative Bias: 38.209

# %%
plt.figure(figsize=(12, 6))

# Plot derivative of w
plt.subplot(1, 2, 1)
plt.plot(range(len(dw_values)), dw_values, marker='o', color='blue', label="Derivative of w")
plt.title("Derivative of Loss with respect to w")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/dw)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

# Plot derivative of b
plt.subplot(1, 2, 2)
plt.plot(range(len(db_values)), db_values, marker='o', color='orange', label="Derivative of b")
plt.title("Derivative of Loss with respect to b")
plt.xlabel("Index of point in dataset")
plt.ylabel("Derivative (dL/db)")
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# OPTIONNAL BUT RECOMMENDED : if you want reload the weight randomly at the first value 

w = random.uniform(mini, maxi)
b = random.uniform(mini, maxi)

# %% [markdown]
# As you can see, the model is learning effectively because the gradients are decreasing. Now, we need to repeat this process for a certain number of epochs *(basically, going through the entire dataset multiple times to give the function more opportunities to learn)*.
#
# Try your best to implement the train function alone ! if you don't find the solution you can check just below this cell, there is a description of what is inside the train function, *good luck !*

# %%
#TODO: Train the model

epochs = 10000
learning_rate = 0.01


for epoch in range(epochs):
    for x, y in train_set:
        y_pred = forward(x)
        loss = squared_error(y, y_pred)
        deriv_w, deriv_b = derivative(x, y, y_pred)
        w -= LEARNING_RATE * deriv_w
        b -= LEARNING_RATE * deriv_b
    print(f"Epoch: {epoch}, Loss: {loss:.5f}")

print("Final Weight:", w)
print("Final Bias:", b)
# Out:
# Epoch: 0, Loss: 33.74762
# Epoch: 1, Loss: 0.64704
# Epoch: 2, Loss: 0.08541
# Epoch: 3, Loss: 0.26974
# Epoch: 4, Loss: 0.30635
# Epoch: 5, Loss: 0.29729
# Epoch: 6, Loss: 0.27892
# Epoch: 7, Loss: 0.25969
# Epoch: 8, Loss: 0.24136
# Epoch: 9, Loss: 0.22423
# Epoch: 10, Loss: 0.20830
# Epoch: 11, Loss: 0.19349
# Epoch: 12, Loss: 0.17974
# Epoch: 13, Loss: 0.16696
# Epoch: 14, Loss: 0.15510
# Epoch: 15, Loss: 0.14407
# Epoch: 16, Loss: 0.13383
# Epoch: 17, Loss: 0.12432
# Epoch: 18, Loss: 0.11548
# Epoch: 19, Loss: 0.10727
# Epoch: 20, Loss: 0.09965
# Epoch: 21, Loss: 0.09257
# Epoch: 22, Loss: 0.08599
# Epoch: 23, Loss: 0.07987
# Epoch: 24, Loss: 0.07420
# Epoch: 25, Loss: 0.06892
# Epoch: 26, Loss: 0.06402
# Epoch: 27, Loss: 0.05947
# Epoch: 28, Loss: 0.05525
# Epoch: 29, Loss: 0.05132
# Epoch: 30, Loss: 0.04767
# Epoch: 31, Loss: 0.04428
# Epoch: 32, Loss: 0.04113
# Epoch: 33, Loss: 0.03821
# Epoch: 34, Loss: 0.03550
# Epoch: 35, Loss: 0.03297
# Epoch: 36, Loss: 0.03063
# Epoch: 37, Loss: 0.02845
# Epoch: 38, Loss: 0.02643
# Epoch: 39, Loss: 0.02455
# Epoch: 40, Loss: 0.02281
# Epoch: 41, Loss: 0.02118
# Epoch: 42, Loss: 0.01968
# Epoch: 43, Loss: 0.01828
# Epoch: 44, Loss: 0.01698
# Epoch: 45, Loss: 0.01577
# Epoch: 46, Loss: 0.01465
# Epoch: 47, Loss: 0.01361
# Epoch: 48, Loss: 0.01264
# Epoch: 49, Loss: 0.01174
# Epoch: 50, Loss: 0.01091
# Epoch: 51, Loss: 0.01013
# Epoch: 52, Loss: 0.00941
# Epoch: 53, Loss: 0.00874
# Epoch: 54, Loss: 0.00812
# Epoch: 55, Loss: 0.00755
# Epoch: 56, Loss: 0.00701
# Epoch: 57, Loss: 0.00651
# Epoch: 58, Loss: 0.00605
# Epoch: 59, Loss: 0.00562
# Epoch: 60, Loss: 0.00522
# Epoch: 61, Loss: 0.00485
# Epoch: 62, Loss: 0.00450
# Epoch: 63, Loss: 0.00418
# Epoch: 64, Loss: 0.00389
# Epoch: 65, Loss: 0.00361
# Epoch: 66, Loss: 0.00335
# Epoch: 67, Loss: 0.00311
# Epoch: 68, Loss: 0.00289
# Epoch: 69, Loss: 0.00269
# Epoch: 70, Loss: 0.00250
# Epoch: 71, Loss: 0.00232
# Epoch: 72, Loss: 0.00215
# Epoch: 73, Loss: 0.00200
# Epoch: 74, Loss: 0.00186
# Epoch: 75, Loss: 0.00173
# Epoch: 76, Loss: 0.00160
# Epoch: 77, Loss: 0.00149
# Epoch: 78, Loss: 0.00138
# Epoch: 79, Loss: 0.00129
# Epoch: 80, Loss: 0.00119
# Epoch: 81, Loss: 0.00111
# Epoch: 82, Loss: 0.00103
# Epoch: 83, Loss: 0.00096
# Epoch: 84, Loss: 0.00089
# Epoch: 85, Loss: 0.00083
# Epoch: 86, Loss: 0.00077
# Epoch: 87, Loss: 0.00071
# Epoch: 88, Loss: 0.00066
# Epoch: 89, Loss: 0.00062
# Epoch: 90, Loss: 0.00057
# Epoch: 91, Loss: 0.00053
# Epoch: 92, Loss: 0.00049
# Epoch: 93, Loss: 0.00046
# Epoch: 94, Loss: 0.00043
# Epoch: 95, Loss: 0.00040
# Epoch: 96, Loss: 0.00037
# Epoch: 97, Loss: 0.00034
# Epoch: 98, Loss: 0.00032
# Epoch: 99, Loss: 0.00029
# Epoch: 100, Loss: 0.00027
# Epoch: 101, Loss: 0.00025
# Epoch: 102, Loss: 0.00024
# Epoch: 103, Loss: 0.00022
# Epoch: 104, Loss: 0.00020
# Epoch: 105, Loss: 0.00019
# Epoch: 106, Loss: 0.00018
# Epoch: 107, Loss: 0.00016
# Epoch: 108, Loss: 0.00015
# Epoch: 109, Loss: 0.00014
# Epoch: 110, Loss: 0.00013
# Epoch: 111, Loss: 0.00012
# Epoch: 112, Loss: 0.00011
# Epoch: 113, Loss: 0.00010
# Epoch: 114, Loss: 0.00010
# Epoch: 115, Loss: 0.00009
# Epoch: 116, Loss: 0.00008
# Epoch: 117, Loss: 0.00008
# Epoch: 118, Loss: 0.00007
# Epoch: 119, Loss: 0.00007
# Epoch: 120, Loss: 0.00006
# Epoch: 121, Loss: 0.00006
# Epoch: 122, Loss: 0.00005
# Epoch: 123, Loss: 0.00005
# Epoch: 124, Loss: 0.00005
# Epoch: 125, Loss: 0.00004
# Epoch: 126, Loss: 0.00004
# Epoch: 127, Loss: 0.00004
# Epoch: 128, Loss: 0.00003
# Epoch: 129, Loss: 0.00003
# Epoch: 130, Loss: 0.00003
# Epoch: 131, Loss: 0.00003
# Epoch: 132, Loss: 0.00003
# Epoch: 133, Loss: 0.00002
# Epoch: 134, Loss: 0.00002
# Epoch: 135, Loss: 0.00002
# Epoch: 136, Loss: 0.00002
# Epoch: 137, Loss: 0.00002
# Epoch: 138, Loss: 0.00002
# Epoch: 139, Loss: 0.00002
# Epoch: 140, Loss: 0.00001
# Epoch: 141, Loss: 0.00001
# Epoch: 142, Loss: 0.00001
# Epoch: 143, Loss: 0.00001
# Epoch: 144, Loss: 0.00001
# Epoch: 145, Loss: 0.00001
# Epoch: 146, Loss: 0.00001
# Epoch: 147, Loss: 0.00001
# Epoch: 148, Loss: 0.00001
# Epoch: 149, Loss: 0.00001
# Epoch: 150, Loss: 0.00001
# Epoch: 151, Loss: 0.00001
# Epoch: 152, Loss: 0.00001
# Epoch: 153, Loss: 0.00001
# Epoch: 154, Loss: 0.00001
# Epoch: 155, Loss: 0.00000
# Epoch: 156, Loss: 0.00000
# Epoch: 157, Loss: 0.00000
# Epoch: 158, Loss: 0.00000
# Epoch: 159, Loss: 0.00000
# Epoch: 160, Loss: 0.00000
# Epoch: 161, Loss: 0.00000
# Epoch: 162, Loss: 0.00000
# Epoch: 163, Loss: 0.00000
# Epoch: 164, Loss: 0.00000
# Epoch: 165, Loss: 0.00000
# Epoch: 166, Loss: 0.00000
# Epoch: 167, Loss: 0.00000
# Epoch: 168, Loss: 0.00000
# Epoch: 169, Loss: 0.00000
# Epoch: 170, Loss: 0.00000
# Epoch: 171, Loss: 0.00000
# Epoch: 172, Loss: 0.00000
# Epoch: 173, Loss: 0.00000
# Epoch: 174, Loss: 0.00000
# Epoch: 175, Loss: 0.00000
# Epoch: 176, Loss: 0.00000
# Epoch: 177, Loss: 0.00000
# Epoch: 178, Loss: 0.00000
# Epoch: 179, Loss: 0.00000
# Epoch: 180, Loss: 0.00000
# Epoch: 181, Loss: 0.00000
# Epoch: 182, Loss: 0.00000
# Epoch: 183, Loss: 0.00000
# Epoch: 184, Loss: 0.00000
# Epoch: 185, Loss: 0.00000
# Epoch: 186, Loss: 0.00000
# Epoch: 187, Loss: 0.00000
# Epoch: 188, Loss: 0.00000
# Epoch: 189, Loss: 0.00000
# Epoch: 190, Loss: 0.00000
# Epoch: 191, Loss: 0.00000
# Epoch: 192, Loss: 0.00000
# Epoch: 193, Loss: 0.00000
# Epoch: 194, Loss: 0.00000
# Epoch: 195, Loss: 0.00000
# Epoch: 196, Loss: 0.00000
# Epoch: 197, Loss: 0.00000
# Epoch: 198, Loss: 0.00000
# Epoch: 199, Loss: 0.00000
# Epoch: 200, Loss: 0.00000
# Epoch: 201, Loss: 0.00000
# Epoch: 202, Loss: 0.00000
# Epoch: 203, Loss: 0.00000
# Epoch: 204, Loss: 0.00000
# Epoch: 205, Loss: 0.00000
# Epoch: 206, Loss: 0.00000
# Epoch: 207, Loss: 0.00000
# Epoch: 208, Loss: 0.00000
# Epoch: 209, Loss: 0.00000
# Epoch: 210, Loss: 0.00000
# Epoch: 211, Loss: 0.00000
# Epoch: 212, Loss: 0.00000
# Epoch: 213, Loss: 0.00000
# Epoch: 214, Loss: 0.00000
# Epoch: 215, Loss: 0.00000
# Epoch: 216, Loss: 0.00000
# Epoch: 217, Loss: 0.00000
# Epoch: 218, Loss: 0.00000
# Epoch: 219, Loss: 0.00000
# Epoch: 220, Loss: 0.00000
# Epoch: 221, Loss: 0.00000
# Epoch: 222, Loss: 0.00000
# Epoch: 223, Loss: 0.00000
# Epoch: 224, Loss: 0.00000
# Epoch: 225, Loss: 0.00000
# Epoch: 226, Loss: 0.00000
# Epoch: 227, Loss: 0.00000
# Epoch: 228, Loss: 0.00000
# Epoch: 229, Loss: 0.00000
# Epoch: 230, Loss: 0.00000
# Epoch: 231, Loss: 0.00000
# Epoch: 232, Loss: 0.00000
# Epoch: 233, Loss: 0.00000
# Epoch: 234, Loss: 0.00000
# Epoch: 235, Loss: 0.00000
# Epoch: 236, Loss: 0.00000
# Epoch: 237, Loss: 0.00000
# Epoch: 238, Loss: 0.00000
# Epoch: 239, Loss: 0.00000
# Epoch: 240, Loss: 0.00000
# Epoch: 241, Loss: 0.00000
# Epoch: 242, Loss: 0.00000
# Epoch: 243, Loss: 0.00000
# Epoch: 244, Loss: 0.00000
# Epoch: 245, Loss: 0.00000
# Epoch: 246, Loss: 0.00000
# Epoch: 247, Loss: 0.00000
# Epoch: 248, Loss: 0.00000
# Epoch: 249, Loss: 0.00000
# Epoch: 250, Loss: 0.00000
# Epoch: 251, Loss: 0.00000
# Epoch: 252, Loss: 0.00000
# Epoch: 253, Loss: 0.00000
# Epoch: 254, Loss: 0.00000
# Epoch: 255, Loss: 0.00000
# Epoch: 256, Loss: 0.00000
# Epoch: 257, Loss: 0.00000
# Epoch: 258, Loss: 0.00000
# Epoch: 259, Loss: 0.00000
# Epoch: 260, Loss: 0.00000
# Epoch: 261, Loss: 0.00000
# Epoch: 262, Loss: 0.00000
# Epoch: 263, Loss: 0.00000
# Epoch: 264, Loss: 0.00000
# Epoch: 265, Loss: 0.00000
# Epoch: 266, Loss: 0.00000
# Epoch: 267, Loss: 0.00000
# Epoch: 268, Loss: 0.00000
# Epoch: 269, Loss: 0.00000
# Epoch: 270, Loss: 0.00000
# Epoch: 271, Loss: 0.00000
# Epoch: 272, Loss: 0.00000
# Epoch: 273, Loss: 0.00000
# Epoch: 274, Loss: 0.00000
# Epoch: 275, Loss: 0.00000
# Epoch: 276, Loss: 0.00000
# Epoch: 277, Loss: 0.00000
# Epoch: 278, Loss: 0.00000
# Epoch: 279, Loss: 0.00000
# Epoch: 280, Loss: 0.00000
# Epoch: 281, Loss: 0.00000
# Epoch: 282, Loss: 0.00000
# Epoch: 283, Loss: 0.00000
# Epoch: 284, Loss: 0.00000
# Epoch: 285, Loss: 0.00000
# Epoch: 286, Loss: 0.00000
# Epoch: 287, Loss: 0.00000
# Epoch: 288, Loss: 0.00000
# Epoch: 289, Loss: 0.00000
# Epoch: 290, Loss: 0.00000
# Epoch: 291, Loss: 0.00000
# Epoch: 292, Loss: 0.00000
# Epoch: 293, Loss: 0.00000
# Epoch: 294, Loss: 0.00000
# Epoch: 295, Loss: 0.00000
# Epoch: 296, Loss: 0.00000
# Epoch: 297, Loss: 0.00000
# Epoch: 298, Loss: 0.00000
# Epoch: 299, Loss: 0.00000
# Epoch: 300, Loss: 0.00000
# Epoch: 301, Loss: 0.00000
# Epoch: 302, Loss: 0.00000
# Epoch: 303, Loss: 0.00000
# Epoch: 304, Loss: 0.00000
# Epoch: 305, Loss: 0.00000
# Epoch: 306, Loss: 0.00000
# Epoch: 307, Loss: 0.00000
# Epoch: 308, Loss: 0.00000
# Epoch: 309, Loss: 0.00000
# Epoch: 310, Loss: 0.00000
# Epoch: 311, Loss: 0.00000
# Epoch: 312, Loss: 0.00000
# Epoch: 313, Loss: 0.00000
# Epoch: 314, Loss: 0.00000
# Epoch: 315, Loss: 0.00000
# Epoch: 316, Loss: 0.00000
# Epoch: 317, Loss: 0.00000
# Epoch: 318, Loss: 0.00000
# Epoch: 319, Loss: 0.00000
# Epoch: 320, Loss: 0.00000
# Epoch: 321, Loss: 0.00000
# Epoch: 322, Loss: 0.00000
# Epoch: 323, Loss: 0.00000
# Epoch: 324, Loss: 0.00000
# Epoch: 325, Loss: 0.00000
# Epoch: 326, Loss: 0.00000
# Epoch: 327, Loss: 0.00000
# Epoch: 328, Loss: 0.00000
# Epoch: 329, Loss: 0.00000
# Epoch: 330, Loss: 0.00000
# Epoch: 331, Loss: 0.00000
# Epoch: 332, Loss: 0.00000
# Epoch: 333, Loss: 0.00000
# Epoch: 334, Loss: 0.00000
# Epoch: 335, Loss: 0.00000
# Epoch: 336, Loss: 0.00000
# Epoch: 337, Loss: 0.00000
# Epoch: 338, Loss: 0.00000
# Epoch: 339, Loss: 0.00000
# Epoch: 340, Loss: 0.00000
# Epoch: 341, Loss: 0.00000
# Epoch: 342, Loss: 0.00000
# Epoch: 343, Loss: 0.00000
# Epoch: 344, Loss: 0.00000
# Epoch: 345, Loss: 0.00000
# Epoch: 346, Loss: 0.00000
# Epoch: 347, Loss: 0.00000
# Epoch: 348, Loss: 0.00000
# Epoch: 349, Loss: 0.00000
# Epoch: 350, Loss: 0.00000
# Epoch: 351, Loss: 0.00000
# Epoch: 352, Loss: 0.00000
# Epoch: 353, Loss: 0.00000
# Epoch: 354, Loss: 0.00000
# Epoch: 355, Loss: 0.00000
# Epoch: 356, Loss: 0.00000
# Epoch: 357, Loss: 0.00000
# Epoch: 358, Loss: 0.00000
# Epoch: 359, Loss: 0.00000
# Epoch: 360, Loss: 0.00000
# Epoch: 361, Loss: 0.00000
# Epoch: 362, Loss: 0.00000
# Epoch: 363, Loss: 0.00000
# Epoch: 364, Loss: 0.00000
# Epoch: 365, Loss: 0.00000
# Epoch: 366, Loss: 0.00000
# Epoch: 367, Loss: 0.00000
# Epoch: 368, Loss: 0.00000
# Epoch: 369, Loss: 0.00000
# Epoch: 370, Loss: 0.00000
# Epoch: 371, Loss: 0.00000
# Epoch: 372, Loss: 0.00000
# Epoch: 373, Loss: 0.00000
# Epoch: 374, Loss: 0.00000
# Epoch: 375, Loss: 0.00000
# Epoch: 376, Loss: 0.00000
# Epoch: 377, Loss: 0.00000
# Epoch: 378, Loss: 0.00000
# Epoch: 379, Loss: 0.00000
# Epoch: 380, Loss: 0.00000
# Epoch: 381, Loss: 0.00000
# Epoch: 382, Loss: 0.00000
# Epoch: 383, Loss: 0.00000
# Epoch: 384, Loss: 0.00000
# Epoch: 385, Loss: 0.00000
# Epoch: 386, Loss: 0.00000
# Epoch: 387, Loss: 0.00000
# Epoch: 388, Loss: 0.00000
# Epoch: 389, Loss: 0.00000
# Epoch: 390, Loss: 0.00000
# Epoch: 391, Loss: 0.00000
# Epoch: 392, Loss: 0.00000
# Epoch: 393, Loss: 0.00000
# Epoch: 394, Loss: 0.00000
# Epoch: 395, Loss: 0.00000
# Epoch: 396, Loss: 0.00000
# Epoch: 397, Loss: 0.00000
# Epoch: 398, Loss: 0.00000
# Epoch: 399, Loss: 0.00000
# Epoch: 400, Loss: 0.00000
# Epoch: 401, Loss: 0.00000
# Epoch: 402, Loss: 0.00000
# Epoch: 403, Loss: 0.00000
# Epoch: 404, Loss: 0.00000
# Epoch: 405, Loss: 0.00000
# Epoch: 406, Loss: 0.00000
# Epoch: 407, Loss: 0.00000
# Epoch: 408, Loss: 0.00000
# Epoch: 409, Loss: 0.00000
# Epoch: 410, Loss: 0.00000
# Epoch: 411, Loss: 0.00000
# Epoch: 412, Loss: 0.00000
# Epoch: 413, Loss: 0.00000
# Epoch: 414, Loss: 0.00000
# Epoch: 415, Loss: 0.00000
# Epoch: 416, Loss: 0.00000
# Epoch: 417, Loss: 0.00000
# Epoch: 418, Loss: 0.00000
# Epoch: 419, Loss: 0.00000
# Epoch: 420, Loss: 0.00000
# Epoch: 421, Loss: 0.00000
# Epoch: 422, Loss: 0.00000
# Epoch: 423, Loss: 0.00000
# Epoch: 424, Loss: 0.00000
# Epoch: 425, Loss: 0.00000
# Epoch: 426, Loss: 0.00000
# Epoch: 427, Loss: 0.00000
# Epoch: 428, Loss: 0.00000
# Epoch: 429, Loss: 0.00000
# Epoch: 430, Loss: 0.00000
# Epoch: 431, Loss: 0.00000
# Epoch: 432, Loss: 0.00000
# Epoch: 433, Loss: 0.00000
# Epoch: 434, Loss: 0.00000
# Epoch: 435, Loss: 0.00000
# Epoch: 436, Loss: 0.00000
# Epoch: 437, Loss: 0.00000
# Epoch: 438, Loss: 0.00000
# Epoch: 439, Loss: 0.00000
# Epoch: 440, Loss: 0.00000
# Epoch: 441, Loss: 0.00000
# Epoch: 442, Loss: 0.00000
# Epoch: 443, Loss: 0.00000
# Epoch: 444, Loss: 0.00000
# Epoch: 445, Loss: 0.00000
# Epoch: 446, Loss: 0.00000
# Epoch: 447, Loss: 0.00000
# Epoch: 448, Loss: 0.00000
# Epoch: 449, Loss: 0.00000
# Epoch: 450, Loss: 0.00000
# Epoch: 451, Loss: 0.00000
# Epoch: 452, Loss: 0.00000
# Epoch: 453, Loss: 0.00000
# Epoch: 454, Loss: 0.00000
# Epoch: 455, Loss: 0.00000
# Epoch: 456, Loss: 0.00000
# Epoch: 457, Loss: 0.00000
# Epoch: 458, Loss: 0.00000
# Epoch: 459, Loss: 0.00000
# Epoch: 460, Loss: 0.00000
# Epoch: 461, Loss: 0.00000
# Epoch: 462, Loss: 0.00000
# Epoch: 463, Loss: 0.00000
# Epoch: 464, Loss: 0.00000
# Epoch: 465, Loss: 0.00000
# Epoch: 466, Loss: 0.00000
# Epoch: 467, Loss: 0.00000
# Epoch: 468, Loss: 0.00000
# Epoch: 469, Loss: 0.00000
# Epoch: 470, Loss: 0.00000
# Epoch: 471, Loss: 0.00000
# Epoch: 472, Loss: 0.00000
# Epoch: 473, Loss: 0.00000
# Epoch: 474, Loss: 0.00000
# Epoch: 475, Loss: 0.00000
# Epoch: 476, Loss: 0.00000
# Epoch: 477, Loss: 0.00000
# Epoch: 478, Loss: 0.00000
# Epoch: 479, Loss: 0.00000
# Epoch: 480, Loss: 0.00000
# Epoch: 481, Loss: 0.00000
# Epoch: 482, Loss: 0.00000
# Epoch: 483, Loss: 0.00000
# Epoch: 484, Loss: 0.00000
# Epoch: 485, Loss: 0.00000
# Epoch: 486, Loss: 0.00000
# Epoch: 487, Loss: 0.00000
# Epoch: 488, Loss: 0.00000
# Epoch: 489, Loss: 0.00000
# Epoch: 490, Loss: 0.00000
# Epoch: 491, Loss: 0.00000
# Epoch: 492, Loss: 0.00000
# Epoch: 493, Loss: 0.00000
# Epoch: 494, Loss: 0.00000
# Epoch: 495, Loss: 0.00000
# Epoch: 496, Loss: 0.00000
# Epoch: 497, Loss: 0.00000
# Epoch: 498, Loss: 0.00000
# Epoch: 499, Loss: 0.00000
# Epoch: 500, Loss: 0.00000
# Epoch: 501, Loss: 0.00000
# Epoch: 502, Loss: 0.00000
# Epoch: 503, Loss: 0.00000
# Epoch: 504, Loss: 0.00000
# Epoch: 505, Loss: 0.00000
# Epoch: 506, Loss: 0.00000
# Epoch: 507, Loss: 0.00000
# Epoch: 508, Loss: 0.00000
# Epoch: 509, Loss: 0.00000
# Epoch: 510, Loss: 0.00000
# Epoch: 511, Loss: 0.00000
# Epoch: 512, Loss: 0.00000
# Epoch: 513, Loss: 0.00000
# Epoch: 514, Loss: 0.00000
# Epoch: 515, Loss: 0.00000
# Epoch: 516, Loss: 0.00000
# Epoch: 517, Loss: 0.00000
# Epoch: 518, Loss: 0.00000
# Epoch: 519, Loss: 0.00000
# Epoch: 520, Loss: 0.00000
# Epoch: 521, Loss: 0.00000
# Epoch: 522, Loss: 0.00000
# Epoch: 523, Loss: 0.00000
# Epoch: 524, Loss: 0.00000
# Epoch: 525, Loss: 0.00000
# Epoch: 526, Loss: 0.00000
# Epoch: 527, Loss: 0.00000
# Epoch: 528, Loss: 0.00000
# Epoch: 529, Loss: 0.00000
# Epoch: 530, Loss: 0.00000
# Epoch: 531, Loss: 0.00000
# Epoch: 532, Loss: 0.00000
# Epoch: 533, Loss: 0.00000
# Epoch: 534, Loss: 0.00000
# Epoch: 535, Loss: 0.00000
# Epoch: 536, Loss: 0.00000
# Epoch: 537, Loss: 0.00000
# Epoch: 538, Loss: 0.00000
# Epoch: 539, Loss: 0.00000
# Epoch: 540, Loss: 0.00000
# Epoch: 541, Loss: 0.00000
# Epoch: 542, Loss: 0.00000
# Epoch: 543, Loss: 0.00000
# Epoch: 544, Loss: 0.00000
# Epoch: 545, Loss: 0.00000
# Epoch: 546, Loss: 0.00000
# Epoch: 547, Loss: 0.00000
# Epoch: 548, Loss: 0.00000
# Epoch: 549, Loss: 0.00000
# Epoch: 550, Loss: 0.00000
# Epoch: 551, Loss: 0.00000
# Epoch: 552, Loss: 0.00000
# Epoch: 553, Loss: 0.00000
# Epoch: 554, Loss: 0.00000
# Epoch: 555, Loss: 0.00000
# Epoch: 556, Loss: 0.00000
# Epoch: 557, Loss: 0.00000
# Epoch: 558, Loss: 0.00000
# Epoch: 559, Loss: 0.00000
# Epoch: 560, Loss: 0.00000
# Epoch: 561, Loss: 0.00000
# Epoch: 562, Loss: 0.00000
# Epoch: 563, Loss: 0.00000
# Epoch: 564, Loss: 0.00000
# Epoch: 565, Loss: 0.00000
# Epoch: 566, Loss: 0.00000
# Epoch: 567, Loss: 0.00000
# Epoch: 568, Loss: 0.00000
# Epoch: 569, Loss: 0.00000
# Epoch: 570, Loss: 0.00000
# Epoch: 571, Loss: 0.00000
# Epoch: 572, Loss: 0.00000
# Epoch: 573, Loss: 0.00000
# Epoch: 574, Loss: 0.00000
# Epoch: 575, Loss: 0.00000
# Epoch: 576, Loss: 0.00000
# Epoch: 577, Loss: 0.00000
# Epoch: 578, Loss: 0.00000
# Epoch: 579, Loss: 0.00000
# Epoch: 580, Loss: 0.00000
# Epoch: 581, Loss: 0.00000
# Epoch: 582, Loss: 0.00000
# Epoch: 583, Loss: 0.00000
# Epoch: 584, Loss: 0.00000
# Epoch: 585, Loss: 0.00000
# Epoch: 586, Loss: 0.00000
# Epoch: 587, Loss: 0.00000
# Epoch: 588, Loss: 0.00000
# Epoch: 589, Loss: 0.00000
# Epoch: 590, Loss: 0.00000
# Epoch: 591, Loss: 0.00000
# Epoch: 592, Loss: 0.00000
# Epoch: 593, Loss: 0.00000
# Epoch: 594, Loss: 0.00000
# Epoch: 595, Loss: 0.00000
# Epoch: 596, Loss: 0.00000
# Epoch: 597, Loss: 0.00000
# Epoch: 598, Loss: 0.00000
# Epoch: 599, Loss: 0.00000
# Epoch: 600, Loss: 0.00000
# Epoch: 601, Loss: 0.00000
# Epoch: 602, Loss: 0.00000
# Epoch: 603, Loss: 0.00000
# Epoch: 604, Loss: 0.00000
# Epoch: 605, Loss: 0.00000
# Epoch: 606, Loss: 0.00000
# Epoch: 607, Loss: 0.00000
# Epoch: 608, Loss: 0.00000
# Epoch: 609, Loss: 0.00000
# Epoch: 610, Loss: 0.00000
# Epoch: 611, Loss: 0.00000
# Epoch: 612, Loss: 0.00000
# Epoch: 613, Loss: 0.00000
# Epoch: 614, Loss: 0.00000
# Epoch: 615, Loss: 0.00000
# Epoch: 616, Loss: 0.00000
# Epoch: 617, Loss: 0.00000
# Epoch: 618, Loss: 0.00000
# Epoch: 619, Loss: 0.00000
# Epoch: 620, Loss: 0.00000
# Epoch: 621, Loss: 0.00000
# Epoch: 622, Loss: 0.00000
# Epoch: 623, Loss: 0.00000
# Epoch: 624, Loss: 0.00000
# Epoch: 625, Loss: 0.00000
# Epoch: 626, Loss: 0.00000
# Epoch: 627, Loss: 0.00000
# Epoch: 628, Loss: 0.00000
# Epoch: 629, Loss: 0.00000
# Epoch: 630, Loss: 0.00000
# Epoch: 631, Loss: 0.00000
# Epoch: 632, Loss: 0.00000
# Epoch: 633, Loss: 0.00000
# Epoch: 634, Loss: 0.00000
# Epoch: 635, Loss: 0.00000
# Epoch: 636, Loss: 0.00000
# Epoch: 637, Loss: 0.00000
# Epoch: 638, Loss: 0.00000
# Epoch: 639, Loss: 0.00000
# Epoch: 640, Loss: 0.00000
# Epoch: 641, Loss: 0.00000
# Epoch: 642, Loss: 0.00000
# Epoch: 643, Loss: 0.00000
# Epoch: 644, Loss: 0.00000
# Epoch: 645, Loss: 0.00000
# Epoch: 646, Loss: 0.00000
# Epoch: 647, Loss: 0.00000
# Epoch: 648, Loss: 0.00000
# Epoch: 649, Loss: 0.00000
# Epoch: 650, Loss: 0.00000
# Epoch: 651, Loss: 0.00000
# Epoch: 652, Loss: 0.00000
# Epoch: 653, Loss: 0.00000
# Epoch: 654, Loss: 0.00000
# Epoch: 655, Loss: 0.00000
# Epoch: 656, Loss: 0.00000
# Epoch: 657, Loss: 0.00000
# Epoch: 658, Loss: 0.00000
# Epoch: 659, Loss: 0.00000
# Epoch: 660, Loss: 0.00000
# Epoch: 661, Loss: 0.00000
# Epoch: 662, Loss: 0.00000
# Epoch: 663, Loss: 0.00000
# Epoch: 664, Loss: 0.00000
# Epoch: 665, Loss: 0.00000
# Epoch: 666, Loss: 0.00000
# Epoch: 667, Loss: 0.00000
# Epoch: 668, Loss: 0.00000
# Epoch: 669, Loss: 0.00000
# Epoch: 670, Loss: 0.00000
# Epoch: 671, Loss: 0.00000
# Epoch: 672, Loss: 0.00000
# Epoch: 673, Loss: 0.00000
# Epoch: 674, Loss: 0.00000
# Epoch: 675, Loss: 0.00000
# Epoch: 676, Loss: 0.00000
# Epoch: 677, Loss: 0.00000
# Epoch: 678, Loss: 0.00000
# Epoch: 679, Loss: 0.00000
# Epoch: 680, Loss: 0.00000
# Epoch: 681, Loss: 0.00000
# Epoch: 682, Loss: 0.00000
# Epoch: 683, Loss: 0.00000
# Epoch: 684, Loss: 0.00000
# Epoch: 685, Loss: 0.00000
# Epoch: 686, Loss: 0.00000
# Epoch: 687, Loss: 0.00000
# Epoch: 688, Loss: 0.00000
# Epoch: 689, Loss: 0.00000
# Epoch: 690, Loss: 0.00000
# Epoch: 691, Loss: 0.00000
# Epoch: 692, Loss: 0.00000
# Epoch: 693, Loss: 0.00000
# Epoch: 694, Loss: 0.00000
# Epoch: 695, Loss: 0.00000
# Epoch: 696, Loss: 0.00000
# Epoch: 697, Loss: 0.00000
# Epoch: 698, Loss: 0.00000
# Epoch: 699, Loss: 0.00000
# Epoch: 700, Loss: 0.00000
# Epoch: 701, Loss: 0.00000
# Epoch: 702, Loss: 0.00000
# Epoch: 703, Loss: 0.00000
# Epoch: 704, Loss: 0.00000
# Epoch: 705, Loss: 0.00000
# Epoch: 706, Loss: 0.00000
# Epoch: 707, Loss: 0.00000
# Epoch: 708, Loss: 0.00000
# Epoch: 709, Loss: 0.00000
# Epoch: 710, Loss: 0.00000
# Epoch: 711, Loss: 0.00000
# Epoch: 712, Loss: 0.00000
# Epoch: 713, Loss: 0.00000
# Epoch: 714, Loss: 0.00000
# Epoch: 715, Loss: 0.00000
# Epoch: 716, Loss: 0.00000
# Epoch: 717, Loss: 0.00000
# Epoch: 718, Loss: 0.00000
# Epoch: 719, Loss: 0.00000
# Epoch: 720, Loss: 0.00000
# Epoch: 721, Loss: 0.00000
# Epoch: 722, Loss: 0.00000
# Epoch: 723, Loss: 0.00000
# Epoch: 724, Loss: 0.00000
# Epoch: 725, Loss: 0.00000
# Epoch: 726, Loss: 0.00000
# Epoch: 727, Loss: 0.00000
# Epoch: 728, Loss: 0.00000
# Epoch: 729, Loss: 0.00000
# Epoch: 730, Loss: 0.00000
# Epoch: 731, Loss: 0.00000
# Epoch: 732, Loss: 0.00000
# Epoch: 733, Loss: 0.00000
# Epoch: 734, Loss: 0.00000
# Epoch: 735, Loss: 0.00000
# Epoch: 736, Loss: 0.00000
# Epoch: 737, Loss: 0.00000
# Epoch: 738, Loss: 0.00000
# Epoch: 739, Loss: 0.00000
# Epoch: 740, Loss: 0.00000
# Epoch: 741, Loss: 0.00000
# Epoch: 742, Loss: 0.00000
# Epoch: 743, Loss: 0.00000
# Epoch: 744, Loss: 0.00000
# Epoch: 745, Loss: 0.00000
# Epoch: 746, Loss: 0.00000
# Epoch: 747, Loss: 0.00000
# Epoch: 748, Loss: 0.00000
# Epoch: 749, Loss: 0.00000
# Epoch: 750, Loss: 0.00000
# Epoch: 751, Loss: 0.00000
# Epoch: 752, Loss: 0.00000
# Epoch: 753, Loss: 0.00000
# Epoch: 754, Loss: 0.00000
# Epoch: 755, Loss: 0.00000
# Epoch: 756, Loss: 0.00000
# Epoch: 757, Loss: 0.00000
# Epoch: 758, Loss: 0.00000
# Epoch: 759, Loss: 0.00000
# Epoch: 760, Loss: 0.00000
# Epoch: 761, Loss: 0.00000
# Epoch: 762, Loss: 0.00000
# Epoch: 763, Loss: 0.00000
# Epoch: 764, Loss: 0.00000
# Epoch: 765, Loss: 0.00000
# Epoch: 766, Loss: 0.00000
# Epoch: 767, Loss: 0.00000
# Epoch: 768, Loss: 0.00000
# Epoch: 769, Loss: 0.00000
# Epoch: 770, Loss: 0.00000
# Epoch: 771, Loss: 0.00000
# Epoch: 772, Loss: 0.00000
# Epoch: 773, Loss: 0.00000
# Epoch: 774, Loss: 0.00000
# Epoch: 775, Loss: 0.00000
# Epoch: 776, Loss: 0.00000
# Epoch: 777, Loss: 0.00000
# Epoch: 778, Loss: 0.00000
# Epoch: 779, Loss: 0.00000
# Epoch: 780, Loss: 0.00000
# Epoch: 781, Loss: 0.00000
# Epoch: 782, Loss: 0.00000
# Epoch: 783, Loss: 0.00000
# Epoch: 784, Loss: 0.00000
# Epoch: 785, Loss: 0.00000
# Epoch: 786, Loss: 0.00000
# Epoch: 787, Loss: 0.00000
# Epoch: 788, Loss: 0.00000
# Epoch: 789, Loss: 0.00000
# Epoch: 790, Loss: 0.00000
# Epoch: 791, Loss: 0.00000
# Epoch: 792, Loss: 0.00000
# Epoch: 793, Loss: 0.00000
# Epoch: 794, Loss: 0.00000
# Epoch: 795, Loss: 0.00000
# Epoch: 796, Loss: 0.00000
# Epoch: 797, Loss: 0.00000
# Epoch: 798, Loss: 0.00000
# Epoch: 799, Loss: 0.00000
# Epoch: 800, Loss: 0.00000
# Epoch: 801, Loss: 0.00000
# Epoch: 802, Loss: 0.00000
# Epoch: 803, Loss: 0.00000
# Epoch: 804, Loss: 0.00000
# Epoch: 805, Loss: 0.00000
# Epoch: 806, Loss: 0.00000
# Epoch: 807, Loss: 0.00000
# Epoch: 808, Loss: 0.00000
# Epoch: 809, Loss: 0.00000
# Epoch: 810, Loss: 0.00000
# Epoch: 811, Loss: 0.00000
# Epoch: 812, Loss: 0.00000
# Epoch: 813, Loss: 0.00000
# Epoch: 814, Loss: 0.00000
# Epoch: 815, Loss: 0.00000
# Epoch: 816, Loss: 0.00000
# Epoch: 817, Loss: 0.00000
# Epoch: 818, Loss: 0.00000
# Epoch: 819, Loss: 0.00000
# Epoch: 820, Loss: 0.00000
# Epoch: 821, Loss: 0.00000
# Epoch: 822, Loss: 0.00000
# Epoch: 823, Loss: 0.00000
# Epoch: 824, Loss: 0.00000
# Epoch: 825, Loss: 0.00000
# Epoch: 826, Loss: 0.00000
# Epoch: 827, Loss: 0.00000
# Epoch: 828, Loss: 0.00000
# Epoch: 829, Loss: 0.00000
# Epoch: 830, Loss: 0.00000
# Epoch: 831, Loss: 0.00000
# Epoch: 832, Loss: 0.00000
# Epoch: 833, Loss: 0.00000
# Epoch: 834, Loss: 0.00000
# Epoch: 835, Loss: 0.00000
# Epoch: 836, Loss: 0.00000
# Epoch: 837, Loss: 0.00000
# Epoch: 838, Loss: 0.00000
# Epoch: 839, Loss: 0.00000
# Epoch: 840, Loss: 0.00000
# Epoch: 841, Loss: 0.00000
# Epoch: 842, Loss: 0.00000
# Epoch: 843, Loss: 0.00000
# Epoch: 844, Loss: 0.00000
# Epoch: 845, Loss: 0.00000
# Epoch: 846, Loss: 0.00000
# Epoch: 847, Loss: 0.00000
# Epoch: 848, Loss: 0.00000
# Epoch: 849, Loss: 0.00000
# Epoch: 850, Loss: 0.00000
# Epoch: 851, Loss: 0.00000
# Epoch: 852, Loss: 0.00000
# Epoch: 853, Loss: 0.00000
# Epoch: 854, Loss: 0.00000
# Epoch: 855, Loss: 0.00000
# Epoch: 856, Loss: 0.00000
# Epoch: 857, Loss: 0.00000
# Epoch: 858, Loss: 0.00000
# Epoch: 859, Loss: 0.00000
# Epoch: 860, Loss: 0.00000
# Epoch: 861, Loss: 0.00000
# Epoch: 862, Loss: 0.00000
# Epoch: 863, Loss: 0.00000
# Epoch: 864, Loss: 0.00000
# Epoch: 865, Loss: 0.00000
# Epoch: 866, Loss: 0.00000
# Epoch: 867, Loss: 0.00000
# Epoch: 868, Loss: 0.00000
# Epoch: 869, Loss: 0.00000
# Epoch: 870, Loss: 0.00000
# Epoch: 871, Loss: 0.00000
# Epoch: 872, Loss: 0.00000
# Epoch: 873, Loss: 0.00000
# Epoch: 874, Loss: 0.00000
# Epoch: 875, Loss: 0.00000
# Epoch: 876, Loss: 0.00000
# Epoch: 877, Loss: 0.00000
# Epoch: 878, Loss: 0.00000
# Epoch: 879, Loss: 0.00000
# Epoch: 880, Loss: 0.00000
# Epoch: 881, Loss: 0.00000
# Epoch: 882, Loss: 0.00000
# Epoch: 883, Loss: 0.00000
# Epoch: 884, Loss: 0.00000
# Epoch: 885, Loss: 0.00000
# Epoch: 886, Loss: 0.00000
# Epoch: 887, Loss: 0.00000
# Epoch: 888, Loss: 0.00000
# Epoch: 889, Loss: 0.00000
# Epoch: 890, Loss: 0.00000
# Epoch: 891, Loss: 0.00000
# Epoch: 892, Loss: 0.00000
# Epoch: 893, Loss: 0.00000
# Epoch: 894, Loss: 0.00000
# Epoch: 895, Loss: 0.00000
# Epoch: 896, Loss: 0.00000
# Epoch: 897, Loss: 0.00000
# Epoch: 898, Loss: 0.00000
# Epoch: 899, Loss: 0.00000
# Epoch: 900, Loss: 0.00000
# Epoch: 901, Loss: 0.00000
# Epoch: 902, Loss: 0.00000
# Epoch: 903, Loss: 0.00000
# Epoch: 904, Loss: 0.00000
# Epoch: 905, Loss: 0.00000
# Epoch: 906, Loss: 0.00000
# Epoch: 907, Loss: 0.00000
# Epoch: 908, Loss: 0.00000
# Epoch: 909, Loss: 0.00000
# Epoch: 910, Loss: 0.00000
# Epoch: 911, Loss: 0.00000
# Epoch: 912, Loss: 0.00000
# Epoch: 913, Loss: 0.00000
# Epoch: 914, Loss: 0.00000
# Epoch: 915, Loss: 0.00000
# Epoch: 916, Loss: 0.00000
# Epoch: 917, Loss: 0.00000
# Epoch: 918, Loss: 0.00000
# Epoch: 919, Loss: 0.00000
# Epoch: 920, Loss: 0.00000
# Epoch: 921, Loss: 0.00000
# Epoch: 922, Loss: 0.00000
# Epoch: 923, Loss: 0.00000
# Epoch: 924, Loss: 0.00000
# Epoch: 925, Loss: 0.00000
# Epoch: 926, Loss: 0.00000
# Epoch: 927, Loss: 0.00000
# Epoch: 928, Loss: 0.00000
# Epoch: 929, Loss: 0.00000
# Epoch: 930, Loss: 0.00000
# Epoch: 931, Loss: 0.00000
# Epoch: 932, Loss: 0.00000
# Epoch: 933, Loss: 0.00000
# Epoch: 934, Loss: 0.00000
# Epoch: 935, Loss: 0.00000
# Epoch: 936, Loss: 0.00000
# Epoch: 937, Loss: 0.00000
# Epoch: 938, Loss: 0.00000
# Epoch: 939, Loss: 0.00000
# Epoch: 940, Loss: 0.00000
# Epoch: 941, Loss: 0.00000
# Epoch: 942, Loss: 0.00000
# Epoch: 943, Loss: 0.00000
# Epoch: 944, Loss: 0.00000
# Epoch: 945, Loss: 0.00000
# Epoch: 946, Loss: 0.00000
# Epoch: 947, Loss: 0.00000
# Epoch: 948, Loss: 0.00000
# Epoch: 949, Loss: 0.00000
# Epoch: 950, Loss: 0.00000
# Epoch: 951, Loss: 0.00000
# Epoch: 952, Loss: 0.00000
# Epoch: 953, Loss: 0.00000
# Epoch: 954, Loss: 0.00000
# Epoch: 955, Loss: 0.00000
# Epoch: 956, Loss: 0.00000
# Epoch: 957, Loss: 0.00000
# Epoch: 958, Loss: 0.00000
# Epoch: 959, Loss: 0.00000
# Epoch: 960, Loss: 0.00000
# Epoch: 961, Loss: 0.00000
# Epoch: 962, Loss: 0.00000
# Epoch: 963, Loss: 0.00000
# Epoch: 964, Loss: 0.00000
# Epoch: 965, Loss: 0.00000
# Epoch: 966, Loss: 0.00000
# Epoch: 967, Loss: 0.00000
# Epoch: 968, Loss: 0.00000
# Epoch: 969, Loss: 0.00000
# Epoch: 970, Loss: 0.00000
# Epoch: 971, Loss: 0.00000
# Epoch: 972, Loss: 0.00000
# Epoch: 973, Loss: 0.00000
# Epoch: 974, Loss: 0.00000
# Epoch: 975, Loss: 0.00000
# Epoch: 976, Loss: 0.00000
# Epoch: 977, Loss: 0.00000
# Epoch: 978, Loss: 0.00000
# Epoch: 979, Loss: 0.00000
# Epoch: 980, Loss: 0.00000
# Epoch: 981, Loss: 0.00000
# Epoch: 982, Loss: 0.00000
# Epoch: 983, Loss: 0.00000
# Epoch: 984, Loss: 0.00000
# Epoch: 985, Loss: 0.00000
# Epoch: 986, Loss: 0.00000
# Epoch: 987, Loss: 0.00000
# Epoch: 988, Loss: 0.00000
# Epoch: 989, Loss: 0.00000
# Epoch: 990, Loss: 0.00000
# Epoch: 991, Loss: 0.00000
# Epoch: 992, Loss: 0.00000
# Epoch: 993, Loss: 0.00000
# Epoch: 994, Loss: 0.00000
# Epoch: 995, Loss: 0.00000
# Epoch: 996, Loss: 0.00000
# Epoch: 997, Loss: 0.00000
# Epoch: 998, Loss: 0.00000
# Epoch: 999, Loss: 0.00000
# Epoch: 1000, Loss: 0.00000
# Epoch: 1001, Loss: 0.00000
# Epoch: 1002, Loss: 0.00000
# Epoch: 1003, Loss: 0.00000
# Epoch: 1004, Loss: 0.00000
# Epoch: 1005, Loss: 0.00000
# Epoch: 1006, Loss: 0.00000
# Epoch: 1007, Loss: 0.00000
# Epoch: 1008, Loss: 0.00000
# Epoch: 1009, Loss: 0.00000
# Epoch: 1010, Loss: 0.00000
# Epoch: 1011, Loss: 0.00000
# Epoch: 1012, Loss: 0.00000
# Epoch: 1013, Loss: 0.00000
# Epoch: 1014, Loss: 0.00000
# Epoch: 1015, Loss: 0.00000
# Epoch: 1016, Loss: 0.00000
# Epoch: 1017, Loss: 0.00000
# Epoch: 1018, Loss: 0.00000
# Epoch: 1019, Loss: 0.00000
# Epoch: 1020, Loss: 0.00000
# Epoch: 1021, Loss: 0.00000
# Epoch: 1022, Loss: 0.00000
# Epoch: 1023, Loss: 0.00000
# Epoch: 1024, Loss: 0.00000
# Epoch: 1025, Loss: 0.00000
# Epoch: 1026, Loss: 0.00000
# Epoch: 1027, Loss: 0.00000
# Epoch: 1028, Loss: 0.00000
# Epoch: 1029, Loss: 0.00000
# Epoch: 1030, Loss: 0.00000
# Epoch: 1031, Loss: 0.00000
# Epoch: 1032, Loss: 0.00000
# Epoch: 1033, Loss: 0.00000
# Epoch: 1034, Loss: 0.00000
# Epoch: 1035, Loss: 0.00000
# Epoch: 1036, Loss: 0.00000
# Epoch: 1037, Loss: 0.00000
# Epoch: 1038, Loss: 0.00000
# Epoch: 1039, Loss: 0.00000
# Epoch: 1040, Loss: 0.00000
# Epoch: 1041, Loss: 0.00000
# Epoch: 1042, Loss: 0.00000
# Epoch: 1043, Loss: 0.00000
# Epoch: 1044, Loss: 0.00000
# Epoch: 1045, Loss: 0.00000
# Epoch: 1046, Loss: 0.00000
# Epoch: 1047, Loss: 0.00000
# Epoch: 1048, Loss: 0.00000
# Epoch: 1049, Loss: 0.00000
# Epoch: 1050, Loss: 0.00000
# Epoch: 1051, Loss: 0.00000
# Epoch: 1052, Loss: 0.00000
# Epoch: 1053, Loss: 0.00000
# Epoch: 1054, Loss: 0.00000
# Epoch: 1055, Loss: 0.00000
# Epoch: 1056, Loss: 0.00000
# Epoch: 1057, Loss: 0.00000
# Epoch: 1058, Loss: 0.00000
# Epoch: 1059, Loss: 0.00000
# Epoch: 1060, Loss: 0.00000
# Epoch: 1061, Loss: 0.00000
# Epoch: 1062, Loss: 0.00000
# Epoch: 1063, Loss: 0.00000
# Epoch: 1064, Loss: 0.00000
# Epoch: 1065, Loss: 0.00000
# Epoch: 1066, Loss: 0.00000
# Epoch: 1067, Loss: 0.00000
# Epoch: 1068, Loss: 0.00000
# Epoch: 1069, Loss: 0.00000
# Epoch: 1070, Loss: 0.00000
# Epoch: 1071, Loss: 0.00000
# Epoch: 1072, Loss: 0.00000
# Epoch: 1073, Loss: 0.00000
# Epoch: 1074, Loss: 0.00000
# Epoch: 1075, Loss: 0.00000
# Epoch: 1076, Loss: 0.00000
# Epoch: 1077, Loss: 0.00000
# Epoch: 1078, Loss: 0.00000
# Epoch: 1079, Loss: 0.00000
# Epoch: 1080, Loss: 0.00000
# Epoch: 1081, Loss: 0.00000
# Epoch: 1082, Loss: 0.00000
# Epoch: 1083, Loss: 0.00000
# Epoch: 1084, Loss: 0.00000
# Epoch: 1085, Loss: 0.00000
# Epoch: 1086, Loss: 0.00000
# Epoch: 1087, Loss: 0.00000
# Epoch: 1088, Loss: 0.00000
# Epoch: 1089, Loss: 0.00000
# Epoch: 1090, Loss: 0.00000
# Epoch: 1091, Loss: 0.00000
# Epoch: 1092, Loss: 0.00000
# Epoch: 1093, Loss: 0.00000
# Epoch: 1094, Loss: 0.00000
# Epoch: 1095, Loss: 0.00000
# Epoch: 1096, Loss: 0.00000
# Epoch: 1097, Loss: 0.00000
# Epoch: 1098, Loss: 0.00000
# Epoch: 1099, Loss: 0.00000
# Epoch: 1100, Loss: 0.00000
# Epoch: 1101, Loss: 0.00000
# Epoch: 1102, Loss: 0.00000
# Epoch: 1103, Loss: 0.00000
# Epoch: 1104, Loss: 0.00000
# Epoch: 1105, Loss: 0.00000
# Epoch: 1106, Loss: 0.00000
# Epoch: 1107, Loss: 0.00000
# Epoch: 1108, Loss: 0.00000
# Epoch: 1109, Loss: 0.00000
# Epoch: 1110, Loss: 0.00000
# Epoch: 1111, Loss: 0.00000
# Epoch: 1112, Loss: 0.00000
# Epoch: 1113, Loss: 0.00000
# Epoch: 1114, Loss: 0.00000
# Epoch: 1115, Loss: 0.00000
# Epoch: 1116, Loss: 0.00000
# Epoch: 1117, Loss: 0.00000
# Epoch: 1118, Loss: 0.00000
# Epoch: 1119, Loss: 0.00000
# Epoch: 1120, Loss: 0.00000
# Epoch: 1121, Loss: 0.00000
# Epoch: 1122, Loss: 0.00000
# Epoch: 1123, Loss: 0.00000
# Epoch: 1124, Loss: 0.00000
# Epoch: 1125, Loss: 0.00000
# Epoch: 1126, Loss: 0.00000
# Epoch: 1127, Loss: 0.00000
# Epoch: 1128, Loss: 0.00000
# Epoch: 1129, Loss: 0.00000
# Epoch: 1130, Loss: 0.00000
# Epoch: 1131, Loss: 0.00000
# Epoch: 1132, Loss: 0.00000
# Epoch: 1133, Loss: 0.00000
# Epoch: 1134, Loss: 0.00000
# Epoch: 1135, Loss: 0.00000
# Epoch: 1136, Loss: 0.00000
# Epoch: 1137, Loss: 0.00000
# Epoch: 1138, Loss: 0.00000
# Epoch: 1139, Loss: 0.00000
# Epoch: 1140, Loss: 0.00000
# Epoch: 1141, Loss: 0.00000
# Epoch: 1142, Loss: 0.00000
# Epoch: 1143, Loss: 0.00000
# Epoch: 1144, Loss: 0.00000
# Epoch: 1145, Loss: 0.00000
# Epoch: 1146, Loss: 0.00000
# Epoch: 1147, Loss: 0.00000
# Epoch: 1148, Loss: 0.00000
# Epoch: 1149, Loss: 0.00000
# Epoch: 1150, Loss: 0.00000
# Epoch: 1151, Loss: 0.00000
# Epoch: 1152, Loss: 0.00000
# Epoch: 1153, Loss: 0.00000
# Epoch: 1154, Loss: 0.00000
# Epoch: 1155, Loss: 0.00000
# Epoch: 1156, Loss: 0.00000
# Epoch: 1157, Loss: 0.00000
# Epoch: 1158, Loss: 0.00000
# Epoch: 1159, Loss: 0.00000
# Epoch: 1160, Loss: 0.00000
# Epoch: 1161, Loss: 0.00000
# Epoch: 1162, Loss: 0.00000
# Epoch: 1163, Loss: 0.00000
# Epoch: 1164, Loss: 0.00000
# Epoch: 1165, Loss: 0.00000
# Epoch: 1166, Loss: 0.00000
# Epoch: 1167, Loss: 0.00000
# Epoch: 1168, Loss: 0.00000
# Epoch: 1169, Loss: 0.00000
# Epoch: 1170, Loss: 0.00000
# Epoch: 1171, Loss: 0.00000
# Epoch: 1172, Loss: 0.00000
# Epoch: 1173, Loss: 0.00000
# Epoch: 1174, Loss: 0.00000
# Epoch: 1175, Loss: 0.00000
# Epoch: 1176, Loss: 0.00000
# Epoch: 1177, Loss: 0.00000
# Epoch: 1178, Loss: 0.00000
# Epoch: 1179, Loss: 0.00000
# Epoch: 1180, Loss: 0.00000
# Epoch: 1181, Loss: 0.00000
# Epoch: 1182, Loss: 0.00000
# Epoch: 1183, Loss: 0.00000
# Epoch: 1184, Loss: 0.00000
# Epoch: 1185, Loss: 0.00000
# Epoch: 1186, Loss: 0.00000
# Epoch: 1187, Loss: 0.00000
# Epoch: 1188, Loss: 0.00000
# Epoch: 1189, Loss: 0.00000
# Epoch: 1190, Loss: 0.00000
# Epoch: 1191, Loss: 0.00000
# Epoch: 1192, Loss: 0.00000
# Epoch: 1193, Loss: 0.00000
# Epoch: 1194, Loss: 0.00000
# Epoch: 1195, Loss: 0.00000
# Epoch: 1196, Loss: 0.00000
# Epoch: 1197, Loss: 0.00000
# Epoch: 1198, Loss: 0.00000
# Epoch: 1199, Loss: 0.00000
# Epoch: 1200, Loss: 0.00000
# Epoch: 1201, Loss: 0.00000
# Epoch: 1202, Loss: 0.00000
# Epoch: 1203, Loss: 0.00000
# Epoch: 1204, Loss: 0.00000
# Epoch: 1205, Loss: 0.00000
# Epoch: 1206, Loss: 0.00000
# Epoch: 1207, Loss: 0.00000
# Epoch: 1208, Loss: 0.00000
# Epoch: 1209, Loss: 0.00000
# Epoch: 1210, Loss: 0.00000
# Epoch: 1211, Loss: 0.00000
# Epoch: 1212, Loss: 0.00000
# Epoch: 1213, Loss: 0.00000
# Epoch: 1214, Loss: 0.00000
# Epoch: 1215, Loss: 0.00000
# Epoch: 1216, Loss: 0.00000
# Epoch: 1217, Loss: 0.00000
# Epoch: 1218, Loss: 0.00000
# Epoch: 1219, Loss: 0.00000
# Epoch: 1220, Loss: 0.00000
# Epoch: 1221, Loss: 0.00000
# Epoch: 1222, Loss: 0.00000
# Epoch: 1223, Loss: 0.00000
# Epoch: 1224, Loss: 0.00000
# Epoch: 1225, Loss: 0.00000
# Epoch: 1226, Loss: 0.00000
# Epoch: 1227, Loss: 0.00000
# Epoch: 1228, Loss: 0.00000
# Epoch: 1229, Loss: 0.00000
# Epoch: 1230, Loss: 0.00000
# Epoch: 1231, Loss: 0.00000
# Epoch: 1232, Loss: 0.00000
# Epoch: 1233, Loss: 0.00000
# Epoch: 1234, Loss: 0.00000
# Epoch: 1235, Loss: 0.00000
# Epoch: 1236, Loss: 0.00000
# Epoch: 1237, Loss: 0.00000
# Epoch: 1238, Loss: 0.00000
# Epoch: 1239, Loss: 0.00000
# Epoch: 1240, Loss: 0.00000
# Epoch: 1241, Loss: 0.00000
# Epoch: 1242, Loss: 0.00000
# Epoch: 1243, Loss: 0.00000
# Epoch: 1244, Loss: 0.00000
# Epoch: 1245, Loss: 0.00000
# Epoch: 1246, Loss: 0.00000
# Epoch: 1247, Loss: 0.00000
# Epoch: 1248, Loss: 0.00000
# Epoch: 1249, Loss: 0.00000
# Epoch: 1250, Loss: 0.00000
# Epoch: 1251, Loss: 0.00000
# Epoch: 1252, Loss: 0.00000
# Epoch: 1253, Loss: 0.00000
# Epoch: 1254, Loss: 0.00000
# Epoch: 1255, Loss: 0.00000
# Epoch: 1256, Loss: 0.00000
# Epoch: 1257, Loss: 0.00000
# Epoch: 1258, Loss: 0.00000
# Epoch: 1259, Loss: 0.00000
# Epoch: 1260, Loss: 0.00000
# Epoch: 1261, Loss: 0.00000
# Epoch: 1262, Loss: 0.00000
# Epoch: 1263, Loss: 0.00000
# Epoch: 1264, Loss: 0.00000
# Epoch: 1265, Loss: 0.00000
# Epoch: 1266, Loss: 0.00000
# Epoch: 1267, Loss: 0.00000
# Epoch: 1268, Loss: 0.00000
# Epoch: 1269, Loss: 0.00000
# Epoch: 1270, Loss: 0.00000
# Epoch: 1271, Loss: 0.00000
# Epoch: 1272, Loss: 0.00000
# Epoch: 1273, Loss: 0.00000
# Epoch: 1274, Loss: 0.00000
# Epoch: 1275, Loss: 0.00000
# Epoch: 1276, Loss: 0.00000
# Epoch: 1277, Loss: 0.00000
# Epoch: 1278, Loss: 0.00000
# Epoch: 1279, Loss: 0.00000
# Epoch: 1280, Loss: 0.00000
# Epoch: 1281, Loss: 0.00000
# Epoch: 1282, Loss: 0.00000
# Epoch: 1283, Loss: 0.00000
# Epoch: 1284, Loss: 0.00000
# Epoch: 1285, Loss: 0.00000
# Epoch: 1286, Loss: 0.00000
# Epoch: 1287, Loss: 0.00000
# Epoch: 1288, Loss: 0.00000
# Epoch: 1289, Loss: 0.00000
# Epoch: 1290, Loss: 0.00000
# Epoch: 1291, Loss: 0.00000
# Epoch: 1292, Loss: 0.00000
# Epoch: 1293, Loss: 0.00000
# Epoch: 1294, Loss: 0.00000
# Epoch: 1295, Loss: 0.00000
# Epoch: 1296, Loss: 0.00000
# Epoch: 1297, Loss: 0.00000
# Epoch: 1298, Loss: 0.00000
# Epoch: 1299, Loss: 0.00000
# Epoch: 1300, Loss: 0.00000
# Epoch: 1301, Loss: 0.00000
# Epoch: 1302, Loss: 0.00000
# Epoch: 1303, Loss: 0.00000
# Epoch: 1304, Loss: 0.00000
# Epoch: 1305, Loss: 0.00000
# Epoch: 1306, Loss: 0.00000
# Epoch: 1307, Loss: 0.00000
# Epoch: 1308, Loss: 0.00000
# Epoch: 1309, Loss: 0.00000
# Epoch: 1310, Loss: 0.00000
# Epoch: 1311, Loss: 0.00000
# Epoch: 1312, Loss: 0.00000
# Epoch: 1313, Loss: 0.00000
# Epoch: 1314, Loss: 0.00000
# Epoch: 1315, Loss: 0.00000
# Epoch: 1316, Loss: 0.00000
# Epoch: 1317, Loss: 0.00000
# Epoch: 1318, Loss: 0.00000
# Epoch: 1319, Loss: 0.00000
# Epoch: 1320, Loss: 0.00000
# Epoch: 1321, Loss: 0.00000
# Epoch: 1322, Loss: 0.00000
# Epoch: 1323, Loss: 0.00000
# Epoch: 1324, Loss: 0.00000
# Epoch: 1325, Loss: 0.00000
# Epoch: 1326, Loss: 0.00000
# Epoch: 1327, Loss: 0.00000
# Epoch: 1328, Loss: 0.00000
# Epoch: 1329, Loss: 0.00000
# Epoch: 1330, Loss: 0.00000
# Epoch: 1331, Loss: 0.00000
# Epoch: 1332, Loss: 0.00000
# Epoch: 1333, Loss: 0.00000
# Epoch: 1334, Loss: 0.00000
# Epoch: 1335, Loss: 0.00000
# Epoch: 1336, Loss: 0.00000
# Epoch: 1337, Loss: 0.00000
# Epoch: 1338, Loss: 0.00000
# Epoch: 1339, Loss: 0.00000
# Epoch: 1340, Loss: 0.00000
# Epoch: 1341, Loss: 0.00000
# Epoch: 1342, Loss: 0.00000
# Epoch: 1343, Loss: 0.00000
# Epoch: 1344, Loss: 0.00000
# Epoch: 1345, Loss: 0.00000
# Epoch: 1346, Loss: 0.00000
# Epoch: 1347, Loss: 0.00000
# Epoch: 1348, Loss: 0.00000
# Epoch: 1349, Loss: 0.00000
# Epoch: 1350, Loss: 0.00000
# Epoch: 1351, Loss: 0.00000
# Epoch: 1352, Loss: 0.00000
# Epoch: 1353, Loss: 0.00000
# Epoch: 1354, Loss: 0.00000
# Epoch: 1355, Loss: 0.00000
# Epoch: 1356, Loss: 0.00000
# Epoch: 1357, Loss: 0.00000
# Epoch: 1358, Loss: 0.00000
# Epoch: 1359, Loss: 0.00000
# Epoch: 1360, Loss: 0.00000
# Epoch: 1361, Loss: 0.00000
# Epoch: 1362, Loss: 0.00000
# Epoch: 1363, Loss: 0.00000
# Epoch: 1364, Loss: 0.00000
# Epoch: 1365, Loss: 0.00000
# Epoch: 1366, Loss: 0.00000
# Epoch: 1367, Loss: 0.00000
# Epoch: 1368, Loss: 0.00000
# Epoch: 1369, Loss: 0.00000
# Epoch: 1370, Loss: 0.00000
# Epoch: 1371, Loss: 0.00000
# Epoch: 1372, Loss: 0.00000
# Epoch: 1373, Loss: 0.00000
# Epoch: 1374, Loss: 0.00000
# Epoch: 1375, Loss: 0.00000
# Epoch: 1376, Loss: 0.00000
# Epoch: 1377, Loss: 0.00000
# Epoch: 1378, Loss: 0.00000
# Epoch: 1379, Loss: 0.00000
# Epoch: 1380, Loss: 0.00000
# Epoch: 1381, Loss: 0.00000
# Epoch: 1382, Loss: 0.00000
# Epoch: 1383, Loss: 0.00000
# Epoch: 1384, Loss: 0.00000
# Epoch: 1385, Loss: 0.00000
# Epoch: 1386, Loss: 0.00000
# Epoch: 1387, Loss: 0.00000
# Epoch: 1388, Loss: 0.00000
# Epoch: 1389, Loss: 0.00000
# Epoch: 1390, Loss: 0.00000
# Epoch: 1391, Loss: 0.00000
# Epoch: 1392, Loss: 0.00000
# Epoch: 1393, Loss: 0.00000
# Epoch: 1394, Loss: 0.00000
# Epoch: 1395, Loss: 0.00000
# Epoch: 1396, Loss: 0.00000
# Epoch: 1397, Loss: 0.00000
# Epoch: 1398, Loss: 0.00000
# Epoch: 1399, Loss: 0.00000
# Epoch: 1400, Loss: 0.00000
# Epoch: 1401, Loss: 0.00000
# Epoch: 1402, Loss: 0.00000
# Epoch: 1403, Loss: 0.00000
# Epoch: 1404, Loss: 0.00000
# Epoch: 1405, Loss: 0.00000
# Epoch: 1406, Loss: 0.00000
# Epoch: 1407, Loss: 0.00000
# Epoch: 1408, Loss: 0.00000
# Epoch: 1409, Loss: 0.00000
# Epoch: 1410, Loss: 0.00000
# Epoch: 1411, Loss: 0.00000
# Epoch: 1412, Loss: 0.00000
# Epoch: 1413, Loss: 0.00000
# Epoch: 1414, Loss: 0.00000
# Epoch: 1415, Loss: 0.00000
# Epoch: 1416, Loss: 0.00000
# Epoch: 1417, Loss: 0.00000
# Epoch: 1418, Loss: 0.00000
# Epoch: 1419, Loss: 0.00000
# Epoch: 1420, Loss: 0.00000
# Epoch: 1421, Loss: 0.00000
# Epoch: 1422, Loss: 0.00000
# Epoch: 1423, Loss: 0.00000
# Epoch: 1424, Loss: 0.00000
# Epoch: 1425, Loss: 0.00000
# Epoch: 1426, Loss: 0.00000
# Epoch: 1427, Loss: 0.00000
# Epoch: 1428, Loss: 0.00000
# Epoch: 1429, Loss: 0.00000
# Epoch: 1430, Loss: 0.00000
# Epoch: 1431, Loss: 0.00000
# Epoch: 1432, Loss: 0.00000
# Epoch: 1433, Loss: 0.00000
# Epoch: 1434, Loss: 0.00000
# Epoch: 1435, Loss: 0.00000
# Epoch: 1436, Loss: 0.00000
# Epoch: 1437, Loss: 0.00000
# Epoch: 1438, Loss: 0.00000
# Epoch: 1439, Loss: 0.00000
# Epoch: 1440, Loss: 0.00000
# Epoch: 1441, Loss: 0.00000
# Epoch: 1442, Loss: 0.00000
# Epoch: 1443, Loss: 0.00000
# Epoch: 1444, Loss: 0.00000
# Epoch: 1445, Loss: 0.00000
# Epoch: 1446, Loss: 0.00000
# Epoch: 1447, Loss: 0.00000
# Epoch: 1448, Loss: 0.00000
# Epoch: 1449, Loss: 0.00000
# Epoch: 1450, Loss: 0.00000
# Epoch: 1451, Loss: 0.00000
# Epoch: 1452, Loss: 0.00000
# Epoch: 1453, Loss: 0.00000
# Epoch: 1454, Loss: 0.00000
# Epoch: 1455, Loss: 0.00000
# Epoch: 1456, Loss: 0.00000
# Epoch: 1457, Loss: 0.00000
# Epoch: 1458, Loss: 0.00000
# Epoch: 1459, Loss: 0.00000
# Epoch: 1460, Loss: 0.00000
# Epoch: 1461, Loss: 0.00000
# Epoch: 1462, Loss: 0.00000
# Epoch: 1463, Loss: 0.00000
# Epoch: 1464, Loss: 0.00000
# Epoch: 1465, Loss: 0.00000
# Epoch: 1466, Loss: 0.00000
# Epoch: 1467, Loss: 0.00000
# Epoch: 1468, Loss: 0.00000
# Epoch: 1469, Loss: 0.00000
# Epoch: 1470, Loss: 0.00000
# Epoch: 1471, Loss: 0.00000
# Epoch: 1472, Loss: 0.00000
# Epoch: 1473, Loss: 0.00000
# Epoch: 1474, Loss: 0.00000
# Epoch: 1475, Loss: 0.00000
# Epoch: 1476, Loss: 0.00000
# Epoch: 1477, Loss: 0.00000
# Epoch: 1478, Loss: 0.00000
# Epoch: 1479, Loss: 0.00000
# Epoch: 1480, Loss: 0.00000
# Epoch: 1481, Loss: 0.00000
# Epoch: 1482, Loss: 0.00000
# Epoch: 1483, Loss: 0.00000
# Epoch: 1484, Loss: 0.00000
# Epoch: 1485, Loss: 0.00000
# Epoch: 1486, Loss: 0.00000
# Epoch: 1487, Loss: 0.00000
# Epoch: 1488, Loss: 0.00000
# Epoch: 1489, Loss: 0.00000
# Epoch: 1490, Loss: 0.00000
# Epoch: 1491, Loss: 0.00000
# Epoch: 1492, Loss: 0.00000
# Epoch: 1493, Loss: 0.00000
# Epoch: 1494, Loss: 0.00000
# Epoch: 1495, Loss: 0.00000
# Epoch: 1496, Loss: 0.00000
# Epoch: 1497, Loss: 0.00000
# Epoch: 1498, Loss: 0.00000
# Epoch: 1499, Loss: 0.00000
# Epoch: 1500, Loss: 0.00000
# Epoch: 1501, Loss: 0.00000
# Epoch: 1502, Loss: 0.00000
# Epoch: 1503, Loss: 0.00000
# Epoch: 1504, Loss: 0.00000
# Epoch: 1505, Loss: 0.00000
# Epoch: 1506, Loss: 0.00000
# Epoch: 1507, Loss: 0.00000
# Epoch: 1508, Loss: 0.00000
# Epoch: 1509, Loss: 0.00000
# Epoch: 1510, Loss: 0.00000
# Epoch: 1511, Loss: 0.00000
# Epoch: 1512, Loss: 0.00000
# Epoch: 1513, Loss: 0.00000
# Epoch: 1514, Loss: 0.00000
# Epoch: 1515, Loss: 0.00000
# Epoch: 1516, Loss: 0.00000
# Epoch: 1517, Loss: 0.00000
# Epoch: 1518, Loss: 0.00000
# Epoch: 1519, Loss: 0.00000
# Epoch: 1520, Loss: 0.00000
# Epoch: 1521, Loss: 0.00000
# Epoch: 1522, Loss: 0.00000
# Epoch: 1523, Loss: 0.00000
# Epoch: 1524, Loss: 0.00000
# Epoch: 1525, Loss: 0.00000
# Epoch: 1526, Loss: 0.00000
# Epoch: 1527, Loss: 0.00000
# Epoch: 1528, Loss: 0.00000
# Epoch: 1529, Loss: 0.00000
# Epoch: 1530, Loss: 0.00000
# Epoch: 1531, Loss: 0.00000
# Epoch: 1532, Loss: 0.00000
# Epoch: 1533, Loss: 0.00000
# Epoch: 1534, Loss: 0.00000
# Epoch: 1535, Loss: 0.00000
# Epoch: 1536, Loss: 0.00000
# Epoch: 1537, Loss: 0.00000
# Epoch: 1538, Loss: 0.00000
# Epoch: 1539, Loss: 0.00000
# Epoch: 1540, Loss: 0.00000
# Epoch: 1541, Loss: 0.00000
# Epoch: 1542, Loss: 0.00000
# Epoch: 1543, Loss: 0.00000
# Epoch: 1544, Loss: 0.00000
# Epoch: 1545, Loss: 0.00000
# Epoch: 1546, Loss: 0.00000
# Epoch: 1547, Loss: 0.00000
# Epoch: 1548, Loss: 0.00000
# Epoch: 1549, Loss: 0.00000
# Epoch: 1550, Loss: 0.00000
# Epoch: 1551, Loss: 0.00000
# Epoch: 1552, Loss: 0.00000
# Epoch: 1553, Loss: 0.00000
# Epoch: 1554, Loss: 0.00000
# Epoch: 1555, Loss: 0.00000
# Epoch: 1556, Loss: 0.00000
# Epoch: 1557, Loss: 0.00000
# Epoch: 1558, Loss: 0.00000
# Epoch: 1559, Loss: 0.00000
# Epoch: 1560, Loss: 0.00000
# Epoch: 1561, Loss: 0.00000
# Epoch: 1562, Loss: 0.00000
# Epoch: 1563, Loss: 0.00000
# Epoch: 1564, Loss: 0.00000
# Epoch: 1565, Loss: 0.00000
# Epoch: 1566, Loss: 0.00000
# Epoch: 1567, Loss: 0.00000
# Epoch: 1568, Loss: 0.00000
# Epoch: 1569, Loss: 0.00000
# Epoch: 1570, Loss: 0.00000
# Epoch: 1571, Loss: 0.00000
# Epoch: 1572, Loss: 0.00000
# Epoch: 1573, Loss: 0.00000
# Epoch: 1574, Loss: 0.00000
# Epoch: 1575, Loss: 0.00000
# Epoch: 1576, Loss: 0.00000
# Epoch: 1577, Loss: 0.00000
# Epoch: 1578, Loss: 0.00000
# Epoch: 1579, Loss: 0.00000
# Epoch: 1580, Loss: 0.00000
# Epoch: 1581, Loss: 0.00000
# Epoch: 1582, Loss: 0.00000
# Epoch: 1583, Loss: 0.00000
# Epoch: 1584, Loss: 0.00000
# Epoch: 1585, Loss: 0.00000
# Epoch: 1586, Loss: 0.00000
# Epoch: 1587, Loss: 0.00000
# Epoch: 1588, Loss: 0.00000
# Epoch: 1589, Loss: 0.00000
# Epoch: 1590, Loss: 0.00000
# Epoch: 1591, Loss: 0.00000
# Epoch: 1592, Loss: 0.00000
# Epoch: 1593, Loss: 0.00000
# Epoch: 1594, Loss: 0.00000
# Epoch: 1595, Loss: 0.00000
# Epoch: 1596, Loss: 0.00000
# Epoch: 1597, Loss: 0.00000
# Epoch: 1598, Loss: 0.00000
# Epoch: 1599, Loss: 0.00000
# Epoch: 1600, Loss: 0.00000
# Epoch: 1601, Loss: 0.00000
# Epoch: 1602, Loss: 0.00000
# Epoch: 1603, Loss: 0.00000
# Epoch: 1604, Loss: 0.00000
# Epoch: 1605, Loss: 0.00000
# Epoch: 1606, Loss: 0.00000
# Epoch: 1607, Loss: 0.00000
# Epoch: 1608, Loss: 0.00000
# Epoch: 1609, Loss: 0.00000
# Epoch: 1610, Loss: 0.00000
# Epoch: 1611, Loss: 0.00000
# Epoch: 1612, Loss: 0.00000
# Epoch: 1613, Loss: 0.00000
# Epoch: 1614, Loss: 0.00000
# Epoch: 1615, Loss: 0.00000
# Epoch: 1616, Loss: 0.00000
# Epoch: 1617, Loss: 0.00000
# Epoch: 1618, Loss: 0.00000
# Epoch: 1619, Loss: 0.00000
# Epoch: 1620, Loss: 0.00000
# Epoch: 1621, Loss: 0.00000
# Epoch: 1622, Loss: 0.00000
# Epoch: 1623, Loss: 0.00000
# Epoch: 1624, Loss: 0.00000
# Epoch: 1625, Loss: 0.00000
# Epoch: 1626, Loss: 0.00000
# Epoch: 1627, Loss: 0.00000
# Epoch: 1628, Loss: 0.00000
# Epoch: 1629, Loss: 0.00000
# Epoch: 1630, Loss: 0.00000
# Epoch: 1631, Loss: 0.00000
# Epoch: 1632, Loss: 0.00000
# Epoch: 1633, Loss: 0.00000
# Epoch: 1634, Loss: 0.00000
# Epoch: 1635, Loss: 0.00000
# Epoch: 1636, Loss: 0.00000
# Epoch: 1637, Loss: 0.00000
# Epoch: 1638, Loss: 0.00000
# Epoch: 1639, Loss: 0.00000
# Epoch: 1640, Loss: 0.00000
# Epoch: 1641, Loss: 0.00000
# Epoch: 1642, Loss: 0.00000
# Epoch: 1643, Loss: 0.00000
# Epoch: 1644, Loss: 0.00000
# Epoch: 1645, Loss: 0.00000
# Epoch: 1646, Loss: 0.00000
# Epoch: 1647, Loss: 0.00000
# Epoch: 1648, Loss: 0.00000
# Epoch: 1649, Loss: 0.00000
# Epoch: 1650, Loss: 0.00000
# Epoch: 1651, Loss: 0.00000
# Epoch: 1652, Loss: 0.00000
# Epoch: 1653, Loss: 0.00000
# Epoch: 1654, Loss: 0.00000
# Epoch: 1655, Loss: 0.00000
# Epoch: 1656, Loss: 0.00000
# Epoch: 1657, Loss: 0.00000
# Epoch: 1658, Loss: 0.00000
# Epoch: 1659, Loss: 0.00000
# Epoch: 1660, Loss: 0.00000
# Epoch: 1661, Loss: 0.00000
# Epoch: 1662, Loss: 0.00000
# Epoch: 1663, Loss: 0.00000
# Epoch: 1664, Loss: 0.00000
# Epoch: 1665, Loss: 0.00000
# Epoch: 1666, Loss: 0.00000
# Epoch: 1667, Loss: 0.00000
# Epoch: 1668, Loss: 0.00000
# Epoch: 1669, Loss: 0.00000
# Epoch: 1670, Loss: 0.00000
# Epoch: 1671, Loss: 0.00000
# Epoch: 1672, Loss: 0.00000
# Epoch: 1673, Loss: 0.00000
# Epoch: 1674, Loss: 0.00000
# Epoch: 1675, Loss: 0.00000
# Epoch: 1676, Loss: 0.00000
# Epoch: 1677, Loss: 0.00000
# Epoch: 1678, Loss: 0.00000
# Epoch: 1679, Loss: 0.00000
# Epoch: 1680, Loss: 0.00000
# Epoch: 1681, Loss: 0.00000
# Epoch: 1682, Loss: 0.00000
# Epoch: 1683, Loss: 0.00000
# Epoch: 1684, Loss: 0.00000
# Epoch: 1685, Loss: 0.00000
# Epoch: 1686, Loss: 0.00000
# Epoch: 1687, Loss: 0.00000
# Epoch: 1688, Loss: 0.00000
# Epoch: 1689, Loss: 0.00000
# Epoch: 1690, Loss: 0.00000
# Epoch: 1691, Loss: 0.00000
# Epoch: 1692, Loss: 0.00000
# Epoch: 1693, Loss: 0.00000
# Epoch: 1694, Loss: 0.00000
# Epoch: 1695, Loss: 0.00000
# Epoch: 1696, Loss: 0.00000
# Epoch: 1697, Loss: 0.00000
# Epoch: 1698, Loss: 0.00000
# Epoch: 1699, Loss: 0.00000
# Epoch: 1700, Loss: 0.00000
# Epoch: 1701, Loss: 0.00000
# Epoch: 1702, Loss: 0.00000
# Epoch: 1703, Loss: 0.00000
# Epoch: 1704, Loss: 0.00000
# Epoch: 1705, Loss: 0.00000
# Epoch: 1706, Loss: 0.00000
# Epoch: 1707, Loss: 0.00000
# Epoch: 1708, Loss: 0.00000
# Epoch: 1709, Loss: 0.00000
# Epoch: 1710, Loss: 0.00000
# Epoch: 1711, Loss: 0.00000
# Epoch: 1712, Loss: 0.00000
# Epoch: 1713, Loss: 0.00000
# Epoch: 1714, Loss: 0.00000
# Epoch: 1715, Loss: 0.00000
# Epoch: 1716, Loss: 0.00000
# Epoch: 1717, Loss: 0.00000
# Epoch: 1718, Loss: 0.00000
# Epoch: 1719, Loss: 0.00000
# Epoch: 1720, Loss: 0.00000
# Epoch: 1721, Loss: 0.00000
# Epoch: 1722, Loss: 0.00000
# Epoch: 1723, Loss: 0.00000
# Epoch: 1724, Loss: 0.00000
# Epoch: 1725, Loss: 0.00000
# Epoch: 1726, Loss: 0.00000
# Epoch: 1727, Loss: 0.00000
# Epoch: 1728, Loss: 0.00000
# Epoch: 1729, Loss: 0.00000
# Epoch: 1730, Loss: 0.00000
# Epoch: 1731, Loss: 0.00000
# Epoch: 1732, Loss: 0.00000
# Epoch: 1733, Loss: 0.00000
# Epoch: 1734, Loss: 0.00000
# Epoch: 1735, Loss: 0.00000
# Epoch: 1736, Loss: 0.00000
# Epoch: 1737, Loss: 0.00000
# Epoch: 1738, Loss: 0.00000
# Epoch: 1739, Loss: 0.00000
# Epoch: 1740, Loss: 0.00000
# Epoch: 1741, Loss: 0.00000
# Epoch: 1742, Loss: 0.00000
# Epoch: 1743, Loss: 0.00000
# Epoch: 1744, Loss: 0.00000
# Epoch: 1745, Loss: 0.00000
# Epoch: 1746, Loss: 0.00000
# Epoch: 1747, Loss: 0.00000
# Epoch: 1748, Loss: 0.00000
# Epoch: 1749, Loss: 0.00000
# Epoch: 1750, Loss: 0.00000
# Epoch: 1751, Loss: 0.00000
# Epoch: 1752, Loss: 0.00000
# Epoch: 1753, Loss: 0.00000
# Epoch: 1754, Loss: 0.00000
# Epoch: 1755, Loss: 0.00000
# Epoch: 1756, Loss: 0.00000
# Epoch: 1757, Loss: 0.00000
# Epoch: 1758, Loss: 0.00000
# Epoch: 1759, Loss: 0.00000
# Epoch: 1760, Loss: 0.00000
# Epoch: 1761, Loss: 0.00000
# Epoch: 1762, Loss: 0.00000
# Epoch: 1763, Loss: 0.00000
# Epoch: 1764, Loss: 0.00000
# Epoch: 1765, Loss: 0.00000
# Epoch: 1766, Loss: 0.00000
# Epoch: 1767, Loss: 0.00000
# Epoch: 1768, Loss: 0.00000
# Epoch: 1769, Loss: 0.00000
# Epoch: 1770, Loss: 0.00000
# Epoch: 1771, Loss: 0.00000
# Epoch: 1772, Loss: 0.00000
# Epoch: 1773, Loss: 0.00000
# Epoch: 1774, Loss: 0.00000
# Epoch: 1775, Loss: 0.00000
# Epoch: 1776, Loss: 0.00000
# Epoch: 1777, Loss: 0.00000
# Epoch: 1778, Loss: 0.00000
# Epoch: 1779, Loss: 0.00000
# Epoch: 1780, Loss: 0.00000
# Epoch: 1781, Loss: 0.00000
# Epoch: 1782, Loss: 0.00000
# Epoch: 1783, Loss: 0.00000
# Epoch: 1784, Loss: 0.00000
# Epoch: 1785, Loss: 0.00000
# Epoch: 1786, Loss: 0.00000
# Epoch: 1787, Loss: 0.00000
# Epoch: 1788, Loss: 0.00000
# Epoch: 1789, Loss: 0.00000
# Epoch: 1790, Loss: 0.00000
# Epoch: 1791, Loss: 0.00000
# Epoch: 1792, Loss: 0.00000
# Epoch: 1793, Loss: 0.00000
# Epoch: 1794, Loss: 0.00000
# Epoch: 1795, Loss: 0.00000
# Epoch: 1796, Loss: 0.00000
# Epoch: 1797, Loss: 0.00000
# Epoch: 1798, Loss: 0.00000
# Epoch: 1799, Loss: 0.00000
# Epoch: 1800, Loss: 0.00000
# Epoch: 1801, Loss: 0.00000
# Epoch: 1802, Loss: 0.00000
# Epoch: 1803, Loss: 0.00000
# Epoch: 1804, Loss: 0.00000
# Epoch: 1805, Loss: 0.00000
# Epoch: 1806, Loss: 0.00000
# Epoch: 1807, Loss: 0.00000
# Epoch: 1808, Loss: 0.00000
# Epoch: 1809, Loss: 0.00000
# Epoch: 1810, Loss: 0.00000
# Epoch: 1811, Loss: 0.00000
# Epoch: 1812, Loss: 0.00000
# Epoch: 1813, Loss: 0.00000
# Epoch: 1814, Loss: 0.00000
# Epoch: 1815, Loss: 0.00000
# Epoch: 1816, Loss: 0.00000
# Epoch: 1817, Loss: 0.00000
# ...
# Epoch: 9410, Loss: 0.00000
# Epoch: 9411, Loss: 0.00000
# Epoch: 9412, Loss: 0.00000
# Epoch: 9413, Loss: 0.00000
# Epoch: 9414, Loss: 0.00000
# Epoch: 9415, Loss: 0.00000
# Epoch: 9416, Loss: 0.00000
# Epoch: 9417, Loss: 0.00000
# Epoch: 9418, Loss: 0.00000
# Epoch: 9419, Loss: 0.00000
# Epoch: 9420, Loss: 0.00000
# Epoch: 9421, Loss: 0.00000
# Epoch: 9422, Loss: 0.00000
# Epoch: 9423, Loss: 0.00000
# Epoch: 9424, Loss: 0.00000
# Epoch: 9425, Loss: 0.00000
# Epoch: 9426, Loss: 0.00000
# Epoch: 9427, Loss: 0.00000
# Epoch: 9428, Loss: 0.00000
# Epoch: 9429, Loss: 0.00000
# Epoch: 9430, Loss: 0.00000
# Epoch: 9431, Loss: 0.00000
# Epoch: 9432, Loss: 0.00000
# Epoch: 9433, Loss: 0.00000
# Epoch: 9434, Loss: 0.00000
# Epoch: 9435, Loss: 0.00000
# Epoch: 9436, Loss: 0.00000
# Epoch: 9437, Loss: 0.00000
# Epoch: 9438, Loss: 0.00000
# Epoch: 9439, Loss: 0.00000
# Epoch: 9440, Loss: 0.00000
# Epoch: 9441, Loss: 0.00000
# Epoch: 9442, Loss: 0.00000
# Epoch: 9443, Loss: 0.00000
# Epoch: 9444, Loss: 0.00000
# Epoch: 9445, Loss: 0.00000
# Epoch: 9446, Loss: 0.00000
# Epoch: 9447, Loss: 0.00000
# Epoch: 9448, Loss: 0.00000
# Epoch: 9449, Loss: 0.00000
# Epoch: 9450, Loss: 0.00000
# Epoch: 9451, Loss: 0.00000
# Epoch: 9452, Loss: 0.00000
# Epoch: 9453, Loss: 0.00000
# Epoch: 9454, Loss: 0.00000
# Epoch: 9455, Loss: 0.00000
# Epoch: 9456, Loss: 0.00000
# Epoch: 9457, Loss: 0.00000
# Epoch: 9458, Loss: 0.00000
# Epoch: 9459, Loss: 0.00000
# Epoch: 9460, Loss: 0.00000
# Epoch: 9461, Loss: 0.00000
# Epoch: 9462, Loss: 0.00000
# Epoch: 9463, Loss: 0.00000
# Epoch: 9464, Loss: 0.00000
# Epoch: 9465, Loss: 0.00000
# Epoch: 9466, Loss: 0.00000
# Epoch: 9467, Loss: 0.00000
# Epoch: 9468, Loss: 0.00000
# Epoch: 9469, Loss: 0.00000
# Epoch: 9470, Loss: 0.00000
# Epoch: 9471, Loss: 0.00000
# Epoch: 9472, Loss: 0.00000
# Epoch: 9473, Loss: 0.00000
# Epoch: 9474, Loss: 0.00000
# Epoch: 9475, Loss: 0.00000
# Epoch: 9476, Loss: 0.00000
# Epoch: 9477, Loss: 0.00000
# Epoch: 9478, Loss: 0.00000
# Epoch: 9479, Loss: 0.00000
# Epoch: 9480, Loss: 0.00000
# Epoch: 9481, Loss: 0.00000
# Epoch: 9482, Loss: 0.00000
# Epoch: 9483, Loss: 0.00000
# Epoch: 9484, Loss: 0.00000
# Epoch: 9485, Loss: 0.00000
# Epoch: 9486, Loss: 0.00000
# Epoch: 9487, Loss: 0.00000
# Epoch: 9488, Loss: 0.00000
# Epoch: 9489, Loss: 0.00000
# Epoch: 9490, Loss: 0.00000
# Epoch: 9491, Loss: 0.00000
# Epoch: 9492, Loss: 0.00000
# Epoch: 9493, Loss: 0.00000
# Epoch: 9494, Loss: 0.00000
# Epoch: 9495, Loss: 0.00000
# Epoch: 9496, Loss: 0.00000
# Epoch: 9497, Loss: 0.00000
# Epoch: 9498, Loss: 0.00000
# Epoch: 9499, Loss: 0.00000
# Epoch: 9500, Loss: 0.00000
# Epoch: 9501, Loss: 0.00000
# Epoch: 9502, Loss: 0.00000
# Epoch: 9503, Loss: 0.00000
# Epoch: 9504, Loss: 0.00000
# Epoch: 9505, Loss: 0.00000
# Epoch: 9506, Loss: 0.00000
# Epoch: 9507, Loss: 0.00000
# Epoch: 9508, Loss: 0.00000
# Epoch: 9509, Loss: 0.00000
# Epoch: 9510, Loss: 0.00000
# Epoch: 9511, Loss: 0.00000
# Epoch: 9512, Loss: 0.00000
# Epoch: 9513, Loss: 0.00000
# Epoch: 9514, Loss: 0.00000
# Epoch: 9515, Loss: 0.00000
# Epoch: 9516, Loss: 0.00000
# Epoch: 9517, Loss: 0.00000
# Epoch: 9518, Loss: 0.00000
# Epoch: 9519, Loss: 0.00000
# Epoch: 9520, Loss: 0.00000
# Epoch: 9521, Loss: 0.00000
# Epoch: 9522, Loss: 0.00000
# Epoch: 9523, Loss: 0.00000
# Epoch: 9524, Loss: 0.00000
# Epoch: 9525, Loss: 0.00000
# Epoch: 9526, Loss: 0.00000
# Epoch: 9527, Loss: 0.00000
# Epoch: 9528, Loss: 0.00000
# Epoch: 9529, Loss: 0.00000
# Epoch: 9530, Loss: 0.00000
# Epoch: 9531, Loss: 0.00000
# Epoch: 9532, Loss: 0.00000
# Epoch: 9533, Loss: 0.00000
# Epoch: 9534, Loss: 0.00000
# Epoch: 9535, Loss: 0.00000
# Epoch: 9536, Loss: 0.00000
# Epoch: 9537, Loss: 0.00000
# Epoch: 9538, Loss: 0.00000
# Epoch: 9539, Loss: 0.00000
# Epoch: 9540, Loss: 0.00000
# Epoch: 9541, Loss: 0.00000
# Epoch: 9542, Loss: 0.00000
# Epoch: 9543, Loss: 0.00000
# Epoch: 9544, Loss: 0.00000
# Epoch: 9545, Loss: 0.00000
# Epoch: 9546, Loss: 0.00000
# Epoch: 9547, Loss: 0.00000
# Epoch: 9548, Loss: 0.00000
# Epoch: 9549, Loss: 0.00000
# Epoch: 9550, Loss: 0.00000
# Epoch: 9551, Loss: 0.00000
# Epoch: 9552, Loss: 0.00000
# Epoch: 9553, Loss: 0.00000
# Epoch: 9554, Loss: 0.00000
# Epoch: 9555, Loss: 0.00000
# Epoch: 9556, Loss: 0.00000
# Epoch: 9557, Loss: 0.00000
# Epoch: 9558, Loss: 0.00000
# Epoch: 9559, Loss: 0.00000
# Epoch: 9560, Loss: 0.00000
# Epoch: 9561, Loss: 0.00000
# Epoch: 9562, Loss: 0.00000
# Epoch: 9563, Loss: 0.00000
# Epoch: 9564, Loss: 0.00000
# Epoch: 9565, Loss: 0.00000
# Epoch: 9566, Loss: 0.00000
# Epoch: 9567, Loss: 0.00000
# Epoch: 9568, Loss: 0.00000
# Epoch: 9569, Loss: 0.00000
# Epoch: 9570, Loss: 0.00000
# Epoch: 9571, Loss: 0.00000
# Epoch: 9572, Loss: 0.00000
# Epoch: 9573, Loss: 0.00000
# Epoch: 9574, Loss: 0.00000
# Epoch: 9575, Loss: 0.00000
# Epoch: 9576, Loss: 0.00000
# Epoch: 9577, Loss: 0.00000
# Epoch: 9578, Loss: 0.00000
# Epoch: 9579, Loss: 0.00000
# Epoch: 9580, Loss: 0.00000
# Epoch: 9581, Loss: 0.00000
# Epoch: 9582, Loss: 0.00000
# Epoch: 9583, Loss: 0.00000
# Epoch: 9584, Loss: 0.00000
# Epoch: 9585, Loss: 0.00000
# Epoch: 9586, Loss: 0.00000
# Epoch: 9587, Loss: 0.00000
# Epoch: 9588, Loss: 0.00000
# Epoch: 9589, Loss: 0.00000
# Epoch: 9590, Loss: 0.00000
# Epoch: 9591, Loss: 0.00000
# Epoch: 9592, Loss: 0.00000
# Epoch: 9593, Loss: 0.00000
# Epoch: 9594, Loss: 0.00000
# Epoch: 9595, Loss: 0.00000
# Epoch: 9596, Loss: 0.00000
# Epoch: 9597, Loss: 0.00000
# Epoch: 9598, Loss: 0.00000
# Epoch: 9599, Loss: 0.00000
# Epoch: 9600, Loss: 0.00000
# Epoch: 9601, Loss: 0.00000
# Epoch: 9602, Loss: 0.00000
# Epoch: 9603, Loss: 0.00000
# Epoch: 9604, Loss: 0.00000
# Epoch: 9605, Loss: 0.00000
# Epoch: 9606, Loss: 0.00000
# Epoch: 9607, Loss: 0.00000
# Epoch: 9608, Loss: 0.00000
# Epoch: 9609, Loss: 0.00000
# Epoch: 9610, Loss: 0.00000
# Epoch: 9611, Loss: 0.00000
# Epoch: 9612, Loss: 0.00000
# Epoch: 9613, Loss: 0.00000
# Epoch: 9614, Loss: 0.00000
# Epoch: 9615, Loss: 0.00000
# Epoch: 9616, Loss: 0.00000
# Epoch: 9617, Loss: 0.00000
# Epoch: 9618, Loss: 0.00000
# Epoch: 9619, Loss: 0.00000
# Epoch: 9620, Loss: 0.00000
# Epoch: 9621, Loss: 0.00000
# Epoch: 9622, Loss: 0.00000
# Epoch: 9623, Loss: 0.00000
# Epoch: 9624, Loss: 0.00000
# Epoch: 9625, Loss: 0.00000
# Epoch: 9626, Loss: 0.00000
# Epoch: 9627, Loss: 0.00000
# Epoch: 9628, Loss: 0.00000
# Epoch: 9629, Loss: 0.00000
# Epoch: 9630, Loss: 0.00000
# Epoch: 9631, Loss: 0.00000
# Epoch: 9632, Loss: 0.00000
# Epoch: 9633, Loss: 0.00000
# Epoch: 9634, Loss: 0.00000
# Epoch: 9635, Loss: 0.00000
# Epoch: 9636, Loss: 0.00000
# Epoch: 9637, Loss: 0.00000
# Epoch: 9638, Loss: 0.00000
# Epoch: 9639, Loss: 0.00000
# Epoch: 9640, Loss: 0.00000
# Epoch: 9641, Loss: 0.00000
# Epoch: 9642, Loss: 0.00000
# Epoch: 9643, Loss: 0.00000
# Epoch: 9644, Loss: 0.00000
# Epoch: 9645, Loss: 0.00000
# Epoch: 9646, Loss: 0.00000
# Epoch: 9647, Loss: 0.00000
# Epoch: 9648, Loss: 0.00000
# Epoch: 9649, Loss: 0.00000
# Epoch: 9650, Loss: 0.00000
# Epoch: 9651, Loss: 0.00000
# Epoch: 9652, Loss: 0.00000
# Epoch: 9653, Loss: 0.00000
# Epoch: 9654, Loss: 0.00000
# Epoch: 9655, Loss: 0.00000
# Epoch: 9656, Loss: 0.00000
# Epoch: 9657, Loss: 0.00000
# Epoch: 9658, Loss: 0.00000
# Epoch: 9659, Loss: 0.00000
# Epoch: 9660, Loss: 0.00000
# Epoch: 9661, Loss: 0.00000
# Epoch: 9662, Loss: 0.00000
# Epoch: 9663, Loss: 0.00000
# Epoch: 9664, Loss: 0.00000
# Epoch: 9665, Loss: 0.00000
# Epoch: 9666, Loss: 0.00000
# Epoch: 9667, Loss: 0.00000
# Epoch: 9668, Loss: 0.00000
# Epoch: 9669, Loss: 0.00000
# Epoch: 9670, Loss: 0.00000
# Epoch: 9671, Loss: 0.00000
# Epoch: 9672, Loss: 0.00000
# Epoch: 9673, Loss: 0.00000
# Epoch: 9674, Loss: 0.00000
# Epoch: 9675, Loss: 0.00000
# Epoch: 9676, Loss: 0.00000
# Epoch: 9677, Loss: 0.00000
# Epoch: 9678, Loss: 0.00000
# Epoch: 9679, Loss: 0.00000
# Epoch: 9680, Loss: 0.00000
# Epoch: 9681, Loss: 0.00000
# Epoch: 9682, Loss: 0.00000
# Epoch: 9683, Loss: 0.00000
# Epoch: 9684, Loss: 0.00000
# Epoch: 9685, Loss: 0.00000
# Epoch: 9686, Loss: 0.00000
# Epoch: 9687, Loss: 0.00000
# Epoch: 9688, Loss: 0.00000
# Epoch: 9689, Loss: 0.00000
# Epoch: 9690, Loss: 0.00000
# Epoch: 9691, Loss: 0.00000
# Epoch: 9692, Loss: 0.00000
# Epoch: 9693, Loss: 0.00000
# Epoch: 9694, Loss: 0.00000
# Epoch: 9695, Loss: 0.00000
# Epoch: 9696, Loss: 0.00000
# Epoch: 9697, Loss: 0.00000
# Epoch: 9698, Loss: 0.00000
# Epoch: 9699, Loss: 0.00000
# Epoch: 9700, Loss: 0.00000
# Epoch: 9701, Loss: 0.00000
# Epoch: 9702, Loss: 0.00000
# Epoch: 9703, Loss: 0.00000
# Epoch: 9704, Loss: 0.00000
# Epoch: 9705, Loss: 0.00000
# Epoch: 9706, Loss: 0.00000
# Epoch: 9707, Loss: 0.00000
# Epoch: 9708, Loss: 0.00000
# Epoch: 9709, Loss: 0.00000
# Epoch: 9710, Loss: 0.00000
# Epoch: 9711, Loss: 0.00000
# Epoch: 9712, Loss: 0.00000
# Epoch: 9713, Loss: 0.00000
# Epoch: 9714, Loss: 0.00000
# Epoch: 9715, Loss: 0.00000
# Epoch: 9716, Loss: 0.00000
# Epoch: 9717, Loss: 0.00000
# Epoch: 9718, Loss: 0.00000
# Epoch: 9719, Loss: 0.00000
# Epoch: 9720, Loss: 0.00000
# Epoch: 9721, Loss: 0.00000
# Epoch: 9722, Loss: 0.00000
# Epoch: 9723, Loss: 0.00000
# Epoch: 9724, Loss: 0.00000
# Epoch: 9725, Loss: 0.00000
# Epoch: 9726, Loss: 0.00000
# Epoch: 9727, Loss: 0.00000
# Epoch: 9728, Loss: 0.00000
# Epoch: 9729, Loss: 0.00000
# Epoch: 9730, Loss: 0.00000
# Epoch: 9731, Loss: 0.00000
# Epoch: 9732, Loss: 0.00000
# Epoch: 9733, Loss: 0.00000
# Epoch: 9734, Loss: 0.00000
# Epoch: 9735, Loss: 0.00000
# Epoch: 9736, Loss: 0.00000
# Epoch: 9737, Loss: 0.00000
# Epoch: 9738, Loss: 0.00000
# Epoch: 9739, Loss: 0.00000
# Epoch: 9740, Loss: 0.00000
# Epoch: 9741, Loss: 0.00000
# Epoch: 9742, Loss: 0.00000
# Epoch: 9743, Loss: 0.00000
# Epoch: 9744, Loss: 0.00000
# Epoch: 9745, Loss: 0.00000
# Epoch: 9746, Loss: 0.00000
# Epoch: 9747, Loss: 0.00000
# Epoch: 9748, Loss: 0.00000
# Epoch: 9749, Loss: 0.00000
# Epoch: 9750, Loss: 0.00000
# Epoch: 9751, Loss: 0.00000
# Epoch: 9752, Loss: 0.00000
# Epoch: 9753, Loss: 0.00000
# Epoch: 9754, Loss: 0.00000
# Epoch: 9755, Loss: 0.00000
# Epoch: 9756, Loss: 0.00000
# Epoch: 9757, Loss: 0.00000
# Epoch: 9758, Loss: 0.00000
# Epoch: 9759, Loss: 0.00000
# Epoch: 9760, Loss: 0.00000
# Epoch: 9761, Loss: 0.00000
# Epoch: 9762, Loss: 0.00000
# Epoch: 9763, Loss: 0.00000
# Epoch: 9764, Loss: 0.00000
# Epoch: 9765, Loss: 0.00000
# Epoch: 9766, Loss: 0.00000
# Epoch: 9767, Loss: 0.00000
# Epoch: 9768, Loss: 0.00000
# Epoch: 9769, Loss: 0.00000
# Epoch: 9770, Loss: 0.00000
# Epoch: 9771, Loss: 0.00000
# Epoch: 9772, Loss: 0.00000
# Epoch: 9773, Loss: 0.00000
# Epoch: 9774, Loss: 0.00000
# Epoch: 9775, Loss: 0.00000
# Epoch: 9776, Loss: 0.00000
# Epoch: 9777, Loss: 0.00000
# Epoch: 9778, Loss: 0.00000
# Epoch: 9779, Loss: 0.00000
# Epoch: 9780, Loss: 0.00000
# Epoch: 9781, Loss: 0.00000
# Epoch: 9782, Loss: 0.00000
# Epoch: 9783, Loss: 0.00000
# Epoch: 9784, Loss: 0.00000
# Epoch: 9785, Loss: 0.00000
# Epoch: 9786, Loss: 0.00000
# Epoch: 9787, Loss: 0.00000
# Epoch: 9788, Loss: 0.00000
# Epoch: 9789, Loss: 0.00000
# Epoch: 9790, Loss: 0.00000
# Epoch: 9791, Loss: 0.00000
# Epoch: 9792, Loss: 0.00000
# Epoch: 9793, Loss: 0.00000
# Epoch: 9794, Loss: 0.00000
# Epoch: 9795, Loss: 0.00000
# Epoch: 9796, Loss: 0.00000
# Epoch: 9797, Loss: 0.00000
# Epoch: 9798, Loss: 0.00000
# Epoch: 9799, Loss: 0.00000
# Epoch: 9800, Loss: 0.00000
# Epoch: 9801, Loss: 0.00000
# Epoch: 9802, Loss: 0.00000
# Epoch: 9803, Loss: 0.00000
# Epoch: 9804, Loss: 0.00000
# Epoch: 9805, Loss: 0.00000
# Epoch: 9806, Loss: 0.00000
# Epoch: 9807, Loss: 0.00000
# Epoch: 9808, Loss: 0.00000
# Epoch: 9809, Loss: 0.00000
# Epoch: 9810, Loss: 0.00000
# Epoch: 9811, Loss: 0.00000
# Epoch: 9812, Loss: 0.00000
# Epoch: 9813, Loss: 0.00000
# Epoch: 9814, Loss: 0.00000
# Epoch: 9815, Loss: 0.00000
# Epoch: 9816, Loss: 0.00000
# Epoch: 9817, Loss: 0.00000
# Epoch: 9818, Loss: 0.00000
# Epoch: 9819, Loss: 0.00000
# Epoch: 9820, Loss: 0.00000
# Epoch: 9821, Loss: 0.00000
# Epoch: 9822, Loss: 0.00000
# Epoch: 9823, Loss: 0.00000
# Epoch: 9824, Loss: 0.00000
# Epoch: 9825, Loss: 0.00000
# Epoch: 9826, Loss: 0.00000
# Epoch: 9827, Loss: 0.00000
# Epoch: 9828, Loss: 0.00000
# Epoch: 9829, Loss: 0.00000
# Epoch: 9830, Loss: 0.00000
# Epoch: 9831, Loss: 0.00000
# Epoch: 9832, Loss: 0.00000
# Epoch: 9833, Loss: 0.00000
# Epoch: 9834, Loss: 0.00000
# Epoch: 9835, Loss: 0.00000
# Epoch: 9836, Loss: 0.00000
# Epoch: 9837, Loss: 0.00000
# Epoch: 9838, Loss: 0.00000
# Epoch: 9839, Loss: 0.00000
# Epoch: 9840, Loss: 0.00000
# Epoch: 9841, Loss: 0.00000
# Epoch: 9842, Loss: 0.00000
# Epoch: 9843, Loss: 0.00000
# Epoch: 9844, Loss: 0.00000
# Epoch: 9845, Loss: 0.00000
# Epoch: 9846, Loss: 0.00000
# Epoch: 9847, Loss: 0.00000
# Epoch: 9848, Loss: 0.00000
# Epoch: 9849, Loss: 0.00000
# Epoch: 9850, Loss: 0.00000
# Epoch: 9851, Loss: 0.00000
# Epoch: 9852, Loss: 0.00000
# Epoch: 9853, Loss: 0.00000
# Epoch: 9854, Loss: 0.00000
# Epoch: 9855, Loss: 0.00000
# Epoch: 9856, Loss: 0.00000
# Epoch: 9857, Loss: 0.00000
# Epoch: 9858, Loss: 0.00000
# Epoch: 9859, Loss: 0.00000
# Epoch: 9860, Loss: 0.00000
# Epoch: 9861, Loss: 0.00000
# Epoch: 9862, Loss: 0.00000
# Epoch: 9863, Loss: 0.00000
# Epoch: 9864, Loss: 0.00000
# Epoch: 9865, Loss: 0.00000
# Epoch: 9866, Loss: 0.00000
# Epoch: 9867, Loss: 0.00000
# Epoch: 9868, Loss: 0.00000
# Epoch: 9869, Loss: 0.00000
# Epoch: 9870, Loss: 0.00000
# Epoch: 9871, Loss: 0.00000
# Epoch: 9872, Loss: 0.00000
# Epoch: 9873, Loss: 0.00000
# Epoch: 9874, Loss: 0.00000
# Epoch: 9875, Loss: 0.00000
# Epoch: 9876, Loss: 0.00000
# Epoch: 9877, Loss: 0.00000
# Epoch: 9878, Loss: 0.00000
# Epoch: 9879, Loss: 0.00000
# Epoch: 9880, Loss: 0.00000
# Epoch: 9881, Loss: 0.00000
# Epoch: 9882, Loss: 0.00000
# Epoch: 9883, Loss: 0.00000
# Epoch: 9884, Loss: 0.00000
# Epoch: 9885, Loss: 0.00000
# Epoch: 9886, Loss: 0.00000
# Epoch: 9887, Loss: 0.00000
# Epoch: 9888, Loss: 0.00000
# Epoch: 9889, Loss: 0.00000
# Epoch: 9890, Loss: 0.00000
# Epoch: 9891, Loss: 0.00000
# Epoch: 9892, Loss: 0.00000
# Epoch: 9893, Loss: 0.00000
# Epoch: 9894, Loss: 0.00000
# Epoch: 9895, Loss: 0.00000
# Epoch: 9896, Loss: 0.00000
# Epoch: 9897, Loss: 0.00000
# Epoch: 9898, Loss: 0.00000
# Epoch: 9899, Loss: 0.00000
# Epoch: 9900, Loss: 0.00000
# Epoch: 9901, Loss: 0.00000
# Epoch: 9902, Loss: 0.00000
# Epoch: 9903, Loss: 0.00000
# Epoch: 9904, Loss: 0.00000
# Epoch: 9905, Loss: 0.00000
# Epoch: 9906, Loss: 0.00000
# Epoch: 9907, Loss: 0.00000
# Epoch: 9908, Loss: 0.00000
# Epoch: 9909, Loss: 0.00000
# Epoch: 9910, Loss: 0.00000
# Epoch: 9911, Loss: 0.00000
# Epoch: 9912, Loss: 0.00000
# Epoch: 9913, Loss: 0.00000
# Epoch: 9914, Loss: 0.00000
# Epoch: 9915, Loss: 0.00000
# Epoch: 9916, Loss: 0.00000
# Epoch: 9917, Loss: 0.00000
# Epoch: 9918, Loss: 0.00000
# Epoch: 9919, Loss: 0.00000
# Epoch: 9920, Loss: 0.00000
# Epoch: 9921, Loss: 0.00000
# Epoch: 9922, Loss: 0.00000
# Epoch: 9923, Loss: 0.00000
# Epoch: 9924, Loss: 0.00000
# Epoch: 9925, Loss: 0.00000
# Epoch: 9926, Loss: 0.00000
# Epoch: 9927, Loss: 0.00000
# Epoch: 9928, Loss: 0.00000
# Epoch: 9929, Loss: 0.00000
# Epoch: 9930, Loss: 0.00000
# Epoch: 9931, Loss: 0.00000
# Epoch: 9932, Loss: 0.00000
# Epoch: 9933, Loss: 0.00000
# Epoch: 9934, Loss: 0.00000
# Epoch: 9935, Loss: 0.00000
# Epoch: 9936, Loss: 0.00000
# Epoch: 9937, Loss: 0.00000
# Epoch: 9938, Loss: 0.00000
# Epoch: 9939, Loss: 0.00000
# Epoch: 9940, Loss: 0.00000
# Epoch: 9941, Loss: 0.00000
# Epoch: 9942, Loss: 0.00000
# Epoch: 9943, Loss: 0.00000
# Epoch: 9944, Loss: 0.00000
# Epoch: 9945, Loss: 0.00000
# Epoch: 9946, Loss: 0.00000
# Epoch: 9947, Loss: 0.00000
# Epoch: 9948, Loss: 0.00000
# Epoch: 9949, Loss: 0.00000
# Epoch: 9950, Loss: 0.00000
# Epoch: 9951, Loss: 0.00000
# Epoch: 9952, Loss: 0.00000
# Epoch: 9953, Loss: 0.00000
# Epoch: 9954, Loss: 0.00000
# Epoch: 9955, Loss: 0.00000
# Epoch: 9956, Loss: 0.00000
# Epoch: 9957, Loss: 0.00000
# Epoch: 9958, Loss: 0.00000
# Epoch: 9959, Loss: 0.00000
# Epoch: 9960, Loss: 0.00000
# Epoch: 9961, Loss: 0.00000
# Epoch: 9962, Loss: 0.00000
# Epoch: 9963, Loss: 0.00000
# Epoch: 9964, Loss: 0.00000
# Epoch: 9965, Loss: 0.00000
# Epoch: 9966, Loss: 0.00000
# Epoch: 9967, Loss: 0.00000
# Epoch: 9968, Loss: 0.00000
# Epoch: 9969, Loss: 0.00000
# Epoch: 9970, Loss: 0.00000
# Epoch: 9971, Loss: 0.00000
# Epoch: 9972, Loss: 0.00000
# Epoch: 9973, Loss: 0.00000
# Epoch: 9974, Loss: 0.00000
# Epoch: 9975, Loss: 0.00000
# Epoch: 9976, Loss: 0.00000
# Epoch: 9977, Loss: 0.00000
# Epoch: 9978, Loss: 0.00000
# Epoch: 9979, Loss: 0.00000
# Epoch: 9980, Loss: 0.00000
# Epoch: 9981, Loss: 0.00000
# Epoch: 9982, Loss: 0.00000
# Epoch: 9983, Loss: 0.00000
# Epoch: 9984, Loss: 0.00000
# Epoch: 9985, Loss: 0.00000
# Epoch: 9986, Loss: 0.00000
# Epoch: 9987, Loss: 0.00000
# Epoch: 9988, Loss: 0.00000
# Epoch: 9989, Loss: 0.00000
# Epoch: 9990, Loss: 0.00000
# Epoch: 9991, Loss: 0.00000
# Epoch: 9992, Loss: 0.00000
# Epoch: 9993, Loss: 0.00000
# Epoch: 9994, Loss: 0.00000
# Epoch: 9995, Loss: 0.00000
# Epoch: 9996, Loss: 0.00000
# Epoch: 9997, Loss: 0.00000
# Epoch: 9998, Loss: 0.00000
# Epoch: 9999, Loss: 0.00000
# Final Weight: 1.9999999999999996
# Final Bias: 1.1313193250247958e-15

# %% [markdown]
# Your goal above is to create the function that will train your function ! A little help of what are the step :
# - Define `Hyperparameters` (epochs and lr)
# - Iterate to your `epochs` and for each epoch to your `train_set`
# - apply a `forward` function to get a `y_pred`
# - calculate the `squared error`
# - calculate the `derivative`
# - apply this derivative to the parameters

# %% [markdown]
# Well done you create your first machine learning function ! you can test is on many example you want by simple run the forward pass :)

# %%
x = 3
print ("Prediction ", forward(x))
# Out:
# Prediction  5.999999999999999

# %%
# Plot the result from -10 to 15 with the actual data
x_range = list(range(-5, 15))
y_pred_range = [forward(x) for x in x_range]

# Actual data points
x_actual = [i[0] for i in train_set]
y_actual = [i[1] for i in train_set]

plt.plot(x_actual, y_actual, 'ro', label='Actual Data')
plt.plot(x_range, y_pred_range, 'b-', label='Predicted Data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Actual vs Predicted Data')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# Congratulations on building your very first machine learning algorithm !! I bet you were itching to dive straight into AI, and here you are, well done, now let's discover another fundametals of machine learning, [logistic regression](<logistic_regression.ipynb>)
